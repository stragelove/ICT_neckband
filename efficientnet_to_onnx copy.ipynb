# %%
import torch
import onnx
import onnxruntime as ort
import netron

# %%
print(torch.__version__)
print(onnx.__version__)
print(ort.get_device())
print(ort.__version__)
# Out:
# 2.7.0+cu126
# 1.18.0
# GPU
# 1.22.0

# %%
MODEL_PATH = "./result/efficientnet_v2_l_best.pt"
ONNX_PATH = "./onnx/efficientnet_v2_l.onnx"
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda

# %%
model = torch.load(MODEL_PATH, map_location=DEVICE, weights_only=False)
model.to(DEVICE)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.002531645569620253, mode=row)
#       )
#       (2): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.005063291139240506, mode=row)
#       )
#       (3): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.007594936708860761, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.010126582278481013, mode=row)
#       )
#       (1): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.012658227848101266, mode=row)
#       )
#       (2): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.015189873417721522, mode=row)
#       )
#       (3): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017721518987341773, mode=row)
#       )
#       (4): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.020253164556962026, mode=row)
#       )
#       (5): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02278481012658228, mode=row)
#       )
#       (6): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02531645569620253, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(256, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.027848101265822787, mode=row)
#       )
#       (1): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.030379746835443044, mode=row)
#       )
#       (2): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03291139240506329, mode=row)
#       )
#       (3): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.035443037974683546, mode=row)
#       )
#       (4): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0379746835443038, mode=row)
#       )
#       (5): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04050632911392405, mode=row)
#       )
#       (6): FusedMBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04303797468354431, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04556962025316456, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04810126582278482, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05063291139240506, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.053164556962025315, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.055696202531645575, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05822784810126583, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06075949367088609, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06329113924050633, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06582278481012659, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06835443037974684, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07088607594936709, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07341772151898734, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0759493670886076, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07848101265822785, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0810126582278481, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08354430379746836, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08607594936708862, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08860759493670886, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09113924050632911, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09367088607594937, mode=row)
#       )
#       (10): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09620253164556963, mode=row)
#       )
#       (11): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09873417721518989, mode=row)
#       )
#       (12): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10126582278481013, mode=row)
#       )
#       (13): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10379746835443039, mode=row)
#       )
#       (14): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10632911392405063, mode=row)
#       )
#       (15): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10886075949367088, mode=row)
#       )
#       (16): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11139240506329115, mode=row)
#       )
#       (17): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11392405063291139, mode=row)
#       )
#       (18): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11645569620253166, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
# ...
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1670886075949367, mode=row)
#       )
#       (20): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16962025316455698, mode=row)
#       )
#       (21): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17215189873417724, mode=row)
#       )
#       (22): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17468354430379748, mode=row)
#       )
#       (23): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17721518987341772, mode=row)
#       )
#       (24): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.179746835443038, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18227848101265823, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1848101265822785, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18734177215189873, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.189873417721519, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19240506329113927, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1949367088607595, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19746835443037977, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.4, inplace=True)
#     (1): Linear(in_features=1280, out_features=5, bias=True)
#   )
# )

# %%
# 더미 생성: (batch, 1, mel_bins, time)
dummy = torch.randn(1, 1, 64, 101, device=DEVICE)

# %%
# onnx 모델 변환
print("ONNX 변환중...")

torch.onnx.export(model, # PyTorch 모델
                dummy, # 입력 텐서 (튜플도 가능)
                ONNX_PATH, # 저장할 파일 경로
                export_params=True, # 모델 파라미터 포함
                opset_version=11, # onnx의 연산자 버전
                input_names=['input'], # 입력 이름
                output_names=['output'], # 출력 이름
                dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}} # 배치 크기를 동적으로 지정
)

print(f"ONNX 변환완료'{ONNX_PATH}'에 저장됨")
# Out:
# ONNX 변환중...
# ONNX 변환완료'./onnx/efficientnet_v2_l.onnx'에 저장됨

# %%
model = onnx.load(ONNX_PATH)
print(onnx.helper.printable_graph(model.graph))
# Out:
# graph main_graph (
#   %input[FLOAT, batch_sizex1x64x101]
# ) initializers (
#   %features.4.0.block.2.fc1.weight[FLOAT, 24x384x1x1]
#   %features.4.0.block.2.fc1.bias[FLOAT, 24]
#   %features.4.0.block.2.fc2.weight[FLOAT, 384x24x1x1]
#   %features.4.0.block.2.fc2.bias[FLOAT, 384]
#   %features.4.1.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.1.block.2.fc1.bias[FLOAT, 48]
#   %features.4.1.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.1.block.2.fc2.bias[FLOAT, 768]
#   %features.4.2.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.2.block.2.fc1.bias[FLOAT, 48]
#   %features.4.2.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.2.block.2.fc2.bias[FLOAT, 768]
#   %features.4.3.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.3.block.2.fc1.bias[FLOAT, 48]
#   %features.4.3.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.3.block.2.fc2.bias[FLOAT, 768]
#   %features.4.4.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.4.block.2.fc1.bias[FLOAT, 48]
#   %features.4.4.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.4.block.2.fc2.bias[FLOAT, 768]
#   %features.4.5.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.5.block.2.fc1.bias[FLOAT, 48]
#   %features.4.5.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.5.block.2.fc2.bias[FLOAT, 768]
#   %features.4.6.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.6.block.2.fc1.bias[FLOAT, 48]
#   %features.4.6.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.6.block.2.fc2.bias[FLOAT, 768]
#   %features.4.7.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.7.block.2.fc1.bias[FLOAT, 48]
#   %features.4.7.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.7.block.2.fc2.bias[FLOAT, 768]
#   %features.4.8.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.8.block.2.fc1.bias[FLOAT, 48]
#   %features.4.8.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.8.block.2.fc2.bias[FLOAT, 768]
#   %features.4.9.block.2.fc1.weight[FLOAT, 48x768x1x1]
#   %features.4.9.block.2.fc1.bias[FLOAT, 48]
#   %features.4.9.block.2.fc2.weight[FLOAT, 768x48x1x1]
#   %features.4.9.block.2.fc2.bias[FLOAT, 768]
#   %features.5.0.block.2.fc1.weight[FLOAT, 48x1152x1x1]
#   %features.5.0.block.2.fc1.bias[FLOAT, 48]
#   %features.5.0.block.2.fc2.weight[FLOAT, 1152x48x1x1]
#   %features.5.0.block.2.fc2.bias[FLOAT, 1152]
#   %features.5.1.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.1.block.2.fc1.bias[FLOAT, 56]
#   %features.5.1.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.1.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.2.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.2.block.2.fc1.bias[FLOAT, 56]
#   %features.5.2.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.2.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.3.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.3.block.2.fc1.bias[FLOAT, 56]
#   %features.5.3.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.3.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.4.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.4.block.2.fc1.bias[FLOAT, 56]
#   %features.5.4.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.4.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.5.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.5.block.2.fc1.bias[FLOAT, 56]
#   %features.5.5.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.5.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.6.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.6.block.2.fc1.bias[FLOAT, 56]
#   %features.5.6.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.6.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.7.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.7.block.2.fc1.bias[FLOAT, 56]
#   %features.5.7.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.7.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.8.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.8.block.2.fc1.bias[FLOAT, 56]
#   %features.5.8.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.8.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.9.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.9.block.2.fc1.bias[FLOAT, 56]
#   %features.5.9.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.9.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.10.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.10.block.2.fc1.bias[FLOAT, 56]
#   %features.5.10.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.10.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.11.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.11.block.2.fc1.bias[FLOAT, 56]
#   %features.5.11.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.11.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.12.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.12.block.2.fc1.bias[FLOAT, 56]
#   %features.5.12.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.12.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.13.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.13.block.2.fc1.bias[FLOAT, 56]
#   %features.5.13.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.13.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.14.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.14.block.2.fc1.bias[FLOAT, 56]
#   %features.5.14.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.14.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.15.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.15.block.2.fc1.bias[FLOAT, 56]
#   %features.5.15.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.15.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.16.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.16.block.2.fc1.bias[FLOAT, 56]
#   %features.5.16.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.16.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.17.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.17.block.2.fc1.bias[FLOAT, 56]
#   %features.5.17.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.17.block.2.fc2.bias[FLOAT, 1344]
#   %features.5.18.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.5.18.block.2.fc1.bias[FLOAT, 56]
#   %features.5.18.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.5.18.block.2.fc2.bias[FLOAT, 1344]
#   %features.6.0.block.2.fc1.weight[FLOAT, 56x1344x1x1]
#   %features.6.0.block.2.fc1.bias[FLOAT, 56]
#   %features.6.0.block.2.fc2.weight[FLOAT, 1344x56x1x1]
#   %features.6.0.block.2.fc2.bias[FLOAT, 1344]
#   %features.6.1.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.1.block.2.fc1.bias[FLOAT, 96]
#   %features.6.1.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.1.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.2.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.2.block.2.fc1.bias[FLOAT, 96]
#   %features.6.2.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.2.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.3.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.3.block.2.fc1.bias[FLOAT, 96]
#   %features.6.3.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.3.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.4.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.4.block.2.fc1.bias[FLOAT, 96]
#   %features.6.4.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.4.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.5.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.5.block.2.fc1.bias[FLOAT, 96]
#   %features.6.5.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.5.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.6.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.6.block.2.fc1.bias[FLOAT, 96]
#   %features.6.6.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.6.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.7.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.7.block.2.fc1.bias[FLOAT, 96]
#   %features.6.7.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.7.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.8.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.8.block.2.fc1.bias[FLOAT, 96]
#   %features.6.8.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.8.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.9.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.9.block.2.fc1.bias[FLOAT, 96]
#   %features.6.9.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.9.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.10.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.10.block.2.fc1.bias[FLOAT, 96]
#   %features.6.10.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.10.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.11.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.11.block.2.fc1.bias[FLOAT, 96]
#   %features.6.11.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.11.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.12.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.12.block.2.fc1.bias[FLOAT, 96]
#   %features.6.12.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.12.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.13.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.13.block.2.fc1.bias[FLOAT, 96]
#   %features.6.13.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.13.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.14.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.14.block.2.fc1.bias[FLOAT, 96]
#   %features.6.14.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.14.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.15.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.15.block.2.fc1.bias[FLOAT, 96]
#   %features.6.15.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.15.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.16.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.16.block.2.fc1.bias[FLOAT, 96]
#   %features.6.16.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.16.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.17.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.17.block.2.fc1.bias[FLOAT, 96]
#   %features.6.17.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.17.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.18.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.18.block.2.fc1.bias[FLOAT, 96]
#   %features.6.18.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.18.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.19.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.19.block.2.fc1.bias[FLOAT, 96]
#   %features.6.19.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.19.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.20.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.20.block.2.fc1.bias[FLOAT, 96]
#   %features.6.20.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.20.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.21.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.21.block.2.fc1.bias[FLOAT, 96]
#   %features.6.21.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.21.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.22.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.22.block.2.fc1.bias[FLOAT, 96]
#   %features.6.22.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.22.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.23.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.23.block.2.fc1.bias[FLOAT, 96]
#   %features.6.23.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.23.block.2.fc2.bias[FLOAT, 2304]
#   %features.6.24.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.6.24.block.2.fc1.bias[FLOAT, 96]
#   %features.6.24.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.6.24.block.2.fc2.bias[FLOAT, 2304]
#   %features.7.0.block.2.fc1.weight[FLOAT, 96x2304x1x1]
#   %features.7.0.block.2.fc1.bias[FLOAT, 96]
#   %features.7.0.block.2.fc2.weight[FLOAT, 2304x96x1x1]
#   %features.7.0.block.2.fc2.bias[FLOAT, 2304]
#   %features.7.1.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.1.block.2.fc1.bias[FLOAT, 160]
#   %features.7.1.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.1.block.2.fc2.bias[FLOAT, 3840]
#   %features.7.2.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.2.block.2.fc1.bias[FLOAT, 160]
#   %features.7.2.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.2.block.2.fc2.bias[FLOAT, 3840]
#   %features.7.3.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.3.block.2.fc1.bias[FLOAT, 160]
#   %features.7.3.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.3.block.2.fc2.bias[FLOAT, 3840]
#   %features.7.4.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.4.block.2.fc1.bias[FLOAT, 160]
#   %features.7.4.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.4.block.2.fc2.bias[FLOAT, 3840]
#   %features.7.5.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.5.block.2.fc1.bias[FLOAT, 160]
#   %features.7.5.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.5.block.2.fc2.bias[FLOAT, 3840]
#   %features.7.6.block.2.fc1.weight[FLOAT, 160x3840x1x1]
#   %features.7.6.block.2.fc1.bias[FLOAT, 160]
#   %features.7.6.block.2.fc2.weight[FLOAT, 3840x160x1x1]
#   %features.7.6.block.2.fc2.bias[FLOAT, 3840]
#   %classifier.1.weight[FLOAT, 5x1280]
#   %classifier.1.bias[FLOAT, 5]
#   %onnx::Conv_2771[FLOAT, 32x1x3x3]
#   %onnx::Conv_2772[FLOAT, 32]
#   %onnx::Conv_2774[FLOAT, 32x32x3x3]
#   %onnx::Conv_2775[FLOAT, 32]
#   %onnx::Conv_2777[FLOAT, 32x32x3x3]
#   %onnx::Conv_2778[FLOAT, 32]
#   %onnx::Conv_2780[FLOAT, 32x32x3x3]
#   %onnx::Conv_2781[FLOAT, 32]
#   %onnx::Conv_2783[FLOAT, 32x32x3x3]
#   %onnx::Conv_2784[FLOAT, 32]
#   %onnx::Conv_2786[FLOAT, 128x32x3x3]
#   %onnx::Conv_2787[FLOAT, 128]
#   %onnx::Conv_2789[FLOAT, 64x128x1x1]
#   %onnx::Conv_2790[FLOAT, 64]
#   %onnx::Conv_2792[FLOAT, 256x64x3x3]
#   %onnx::Conv_2793[FLOAT, 256]
#   %onnx::Conv_2795[FLOAT, 64x256x1x1]
#   %onnx::Conv_2796[FLOAT, 64]
#   %onnx::Conv_2798[FLOAT, 256x64x3x3]
#   %onnx::Conv_2799[FLOAT, 256]
#   %onnx::Conv_2801[FLOAT, 64x256x1x1]
#   %onnx::Conv_2802[FLOAT, 64]
#   %onnx::Conv_2804[FLOAT, 256x64x3x3]
#   %onnx::Conv_2805[FLOAT, 256]
#   %onnx::Conv_2807[FLOAT, 64x256x1x1]
#   %onnx::Conv_2808[FLOAT, 64]
#   %onnx::Conv_2810[FLOAT, 256x64x3x3]
#   %onnx::Conv_2811[FLOAT, 256]
#   %onnx::Conv_2813[FLOAT, 64x256x1x1]
#   %onnx::Conv_2814[FLOAT, 64]
#   %onnx::Conv_2816[FLOAT, 256x64x3x3]
#   %onnx::Conv_2817[FLOAT, 256]
#   %onnx::Conv_2819[FLOAT, 64x256x1x1]
#   %onnx::Conv_2820[FLOAT, 64]
#   %onnx::Conv_2822[FLOAT, 256x64x3x3]
#   %onnx::Conv_2823[FLOAT, 256]
#   %onnx::Conv_2825[FLOAT, 64x256x1x1]
#   %onnx::Conv_2826[FLOAT, 64]
#   %onnx::Conv_2828[FLOAT, 256x64x3x3]
#   %onnx::Conv_2829[FLOAT, 256]
#   %onnx::Conv_2831[FLOAT, 96x256x1x1]
#   %onnx::Conv_2832[FLOAT, 96]
#   %onnx::Conv_2834[FLOAT, 384x96x3x3]
#   %onnx::Conv_2835[FLOAT, 384]
#   %onnx::Conv_2837[FLOAT, 96x384x1x1]
#   %onnx::Conv_2838[FLOAT, 96]
#   %onnx::Conv_2840[FLOAT, 384x96x3x3]
#   %onnx::Conv_2841[FLOAT, 384]
#   %onnx::Conv_2843[FLOAT, 96x384x1x1]
#   %onnx::Conv_2844[FLOAT, 96]
#   %onnx::Conv_2846[FLOAT, 384x96x3x3]
#   %onnx::Conv_2847[FLOAT, 384]
#   %onnx::Conv_2849[FLOAT, 96x384x1x1]
#   %onnx::Conv_2850[FLOAT, 96]
#   %onnx::Conv_2852[FLOAT, 384x96x3x3]
#   %onnx::Conv_2853[FLOAT, 384]
#   %onnx::Conv_2855[FLOAT, 96x384x1x1]
#   %onnx::Conv_2856[FLOAT, 96]
#   %onnx::Conv_2858[FLOAT, 384x96x3x3]
#   %onnx::Conv_2859[FLOAT, 384]
#   %onnx::Conv_2861[FLOAT, 96x384x1x1]
#   %onnx::Conv_2862[FLOAT, 96]
#   %onnx::Conv_2864[FLOAT, 384x96x3x3]
#   %onnx::Conv_2865[FLOAT, 384]
#   %onnx::Conv_2867[FLOAT, 96x384x1x1]
#   %onnx::Conv_2868[FLOAT, 96]
#   %onnx::Conv_2870[FLOAT, 384x96x1x1]
#   %onnx::Conv_2871[FLOAT, 384]
#   %onnx::Conv_2873[FLOAT, 384x1x3x3]
#   %onnx::Conv_2874[FLOAT, 384]
#   %onnx::Conv_2876[FLOAT, 192x384x1x1]
#   %onnx::Conv_2877[FLOAT, 192]
#   %onnx::Conv_2879[FLOAT, 768x192x1x1]
#   %onnx::Conv_2880[FLOAT, 768]
#   %onnx::Conv_2882[FLOAT, 768x1x3x3]
#   %onnx::Conv_2883[FLOAT, 768]
#   %onnx::Conv_2885[FLOAT, 192x768x1x1]
#   %onnx::Conv_2886[FLOAT, 192]
#   %onnx::Conv_2888[FLOAT, 768x192x1x1]
#   %onnx::Conv_2889[FLOAT, 768]
#   %onnx::Conv_2891[FLOAT, 768x1x3x3]
#   %onnx::Conv_2892[FLOAT, 768]
#   %onnx::Conv_2894[FLOAT, 192x768x1x1]
#   %onnx::Conv_2895[FLOAT, 192]
#   %onnx::Conv_2897[FLOAT, 768x192x1x1]
#   %onnx::Conv_2898[FLOAT, 768]
#   %onnx::Conv_2900[FLOAT, 768x1x3x3]
#   %onnx::Conv_2901[FLOAT, 768]
#   %onnx::Conv_2903[FLOAT, 192x768x1x1]
#   %onnx::Conv_2904[FLOAT, 192]
#   %onnx::Conv_2906[FLOAT, 768x192x1x1]
#   %onnx::Conv_2907[FLOAT, 768]
#   %onnx::Conv_2909[FLOAT, 768x1x3x3]
#   %onnx::Conv_2910[FLOAT, 768]
#   %onnx::Conv_2912[FLOAT, 192x768x1x1]
#   %onnx::Conv_2913[FLOAT, 192]
#   %onnx::Conv_2915[FLOAT, 768x192x1x1]
#   %onnx::Conv_2916[FLOAT, 768]
#   %onnx::Conv_2918[FLOAT, 768x1x3x3]
#   %onnx::Conv_2919[FLOAT, 768]
#   %onnx::Conv_2921[FLOAT, 192x768x1x1]
#   %onnx::Conv_2922[FLOAT, 192]
#   %onnx::Conv_2924[FLOAT, 768x192x1x1]
#   %onnx::Conv_2925[FLOAT, 768]
#   %onnx::Conv_2927[FLOAT, 768x1x3x3]
#   %onnx::Conv_2928[FLOAT, 768]
#   %onnx::Conv_2930[FLOAT, 192x768x1x1]
#   %onnx::Conv_2931[FLOAT, 192]
#   %onnx::Conv_2933[FLOAT, 768x192x1x1]
#   %onnx::Conv_2934[FLOAT, 768]
#   %onnx::Conv_2936[FLOAT, 768x1x3x3]
#   %onnx::Conv_2937[FLOAT, 768]
#   %onnx::Conv_2939[FLOAT, 192x768x1x1]
#   %onnx::Conv_2940[FLOAT, 192]
#   %onnx::Conv_2942[FLOAT, 768x192x1x1]
#   %onnx::Conv_2943[FLOAT, 768]
#   %onnx::Conv_2945[FLOAT, 768x1x3x3]
#   %onnx::Conv_2946[FLOAT, 768]
#   %onnx::Conv_2948[FLOAT, 192x768x1x1]
#   %onnx::Conv_2949[FLOAT, 192]
#   %onnx::Conv_2951[FLOAT, 768x192x1x1]
#   %onnx::Conv_2952[FLOAT, 768]
#   %onnx::Conv_2954[FLOAT, 768x1x3x3]
#   %onnx::Conv_2955[FLOAT, 768]
#   %onnx::Conv_2957[FLOAT, 192x768x1x1]
#   %onnx::Conv_2958[FLOAT, 192]
#   %onnx::Conv_2960[FLOAT, 1152x192x1x1]
#   %onnx::Conv_2961[FLOAT, 1152]
#   %onnx::Conv_2963[FLOAT, 1152x1x3x3]
#   %onnx::Conv_2964[FLOAT, 1152]
#   %onnx::Conv_2966[FLOAT, 224x1152x1x1]
#   %onnx::Conv_2967[FLOAT, 224]
#   %onnx::Conv_2969[FLOAT, 1344x224x1x1]
#   %onnx::Conv_2970[FLOAT, 1344]
#   %onnx::Conv_2972[FLOAT, 1344x1x3x3]
#   %onnx::Conv_2973[FLOAT, 1344]
#   %onnx::Conv_2975[FLOAT, 224x1344x1x1]
#   %onnx::Conv_2976[FLOAT, 224]
#   %onnx::Conv_2978[FLOAT, 1344x224x1x1]
#   %onnx::Conv_2979[FLOAT, 1344]
#   %onnx::Conv_2981[FLOAT, 1344x1x3x3]
#   %onnx::Conv_2982[FLOAT, 1344]
#   %onnx::Conv_2984[FLOAT, 224x1344x1x1]
#   %onnx::Conv_2985[FLOAT, 224]
#   %onnx::Conv_2987[FLOAT, 1344x224x1x1]
#   %onnx::Conv_2988[FLOAT, 1344]
#   %onnx::Conv_2990[FLOAT, 1344x1x3x3]
#   %onnx::Conv_2991[FLOAT, 1344]
#   %onnx::Conv_2993[FLOAT, 224x1344x1x1]
#   %onnx::Conv_2994[FLOAT, 224]
#   %onnx::Conv_2996[FLOAT, 1344x224x1x1]
#   %onnx::Conv_2997[FLOAT, 1344]
#   %onnx::Conv_2999[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3000[FLOAT, 1344]
#   %onnx::Conv_3002[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3003[FLOAT, 224]
#   %onnx::Conv_3005[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3006[FLOAT, 1344]
#   %onnx::Conv_3008[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3009[FLOAT, 1344]
#   %onnx::Conv_3011[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3012[FLOAT, 224]
#   %onnx::Conv_3014[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3015[FLOAT, 1344]
#   %onnx::Conv_3017[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3018[FLOAT, 1344]
#   %onnx::Conv_3020[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3021[FLOAT, 224]
#   %onnx::Conv_3023[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3024[FLOAT, 1344]
#   %onnx::Conv_3026[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3027[FLOAT, 1344]
#   %onnx::Conv_3029[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3030[FLOAT, 224]
#   %onnx::Conv_3032[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3033[FLOAT, 1344]
#   %onnx::Conv_3035[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3036[FLOAT, 1344]
#   %onnx::Conv_3038[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3039[FLOAT, 224]
#   %onnx::Conv_3041[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3042[FLOAT, 1344]
#   %onnx::Conv_3044[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3045[FLOAT, 1344]
#   %onnx::Conv_3047[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3048[FLOAT, 224]
#   %onnx::Conv_3050[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3051[FLOAT, 1344]
#   %onnx::Conv_3053[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3054[FLOAT, 1344]
#   %onnx::Conv_3056[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3057[FLOAT, 224]
#   %onnx::Conv_3059[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3060[FLOAT, 1344]
#   %onnx::Conv_3062[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3063[FLOAT, 1344]
#   %onnx::Conv_3065[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3066[FLOAT, 224]
#   %onnx::Conv_3068[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3069[FLOAT, 1344]
#   %onnx::Conv_3071[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3072[FLOAT, 1344]
#   %onnx::Conv_3074[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3075[FLOAT, 224]
#   %onnx::Conv_3077[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3078[FLOAT, 1344]
#   %onnx::Conv_3080[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3081[FLOAT, 1344]
#   %onnx::Conv_3083[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3084[FLOAT, 224]
#   %onnx::Conv_3086[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3087[FLOAT, 1344]
#   %onnx::Conv_3089[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3090[FLOAT, 1344]
#   %onnx::Conv_3092[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3093[FLOAT, 224]
#   %onnx::Conv_3095[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3096[FLOAT, 1344]
#   %onnx::Conv_3098[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3099[FLOAT, 1344]
#   %onnx::Conv_3101[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3102[FLOAT, 224]
#   %onnx::Conv_3104[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3105[FLOAT, 1344]
#   %onnx::Conv_3107[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3108[FLOAT, 1344]
#   %onnx::Conv_3110[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3111[FLOAT, 224]
#   %onnx::Conv_3113[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3114[FLOAT, 1344]
#   %onnx::Conv_3116[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3117[FLOAT, 1344]
#   %onnx::Conv_3119[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3120[FLOAT, 224]
#   %onnx::Conv_3122[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3123[FLOAT, 1344]
#   %onnx::Conv_3125[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3126[FLOAT, 1344]
#   %onnx::Conv_3128[FLOAT, 224x1344x1x1]
#   %onnx::Conv_3129[FLOAT, 224]
#   %onnx::Conv_3131[FLOAT, 1344x224x1x1]
#   %onnx::Conv_3132[FLOAT, 1344]
#   %onnx::Conv_3134[FLOAT, 1344x1x3x3]
#   %onnx::Conv_3135[FLOAT, 1344]
#   %onnx::Conv_3137[FLOAT, 384x1344x1x1]
#   %onnx::Conv_3138[FLOAT, 384]
#   %onnx::Conv_3140[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3141[FLOAT, 2304]
#   %onnx::Conv_3143[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3144[FLOAT, 2304]
#   %onnx::Conv_3146[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3147[FLOAT, 384]
#   %onnx::Conv_3149[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3150[FLOAT, 2304]
#   %onnx::Conv_3152[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3153[FLOAT, 2304]
#   %onnx::Conv_3155[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3156[FLOAT, 384]
#   %onnx::Conv_3158[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3159[FLOAT, 2304]
#   %onnx::Conv_3161[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3162[FLOAT, 2304]
#   %onnx::Conv_3164[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3165[FLOAT, 384]
#   %onnx::Conv_3167[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3168[FLOAT, 2304]
#   %onnx::Conv_3170[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3171[FLOAT, 2304]
#   %onnx::Conv_3173[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3174[FLOAT, 384]
#   %onnx::Conv_3176[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3177[FLOAT, 2304]
#   %onnx::Conv_3179[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3180[FLOAT, 2304]
#   %onnx::Conv_3182[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3183[FLOAT, 384]
#   %onnx::Conv_3185[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3186[FLOAT, 2304]
#   %onnx::Conv_3188[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3189[FLOAT, 2304]
#   %onnx::Conv_3191[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3192[FLOAT, 384]
#   %onnx::Conv_3194[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3195[FLOAT, 2304]
#   %onnx::Conv_3197[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3198[FLOAT, 2304]
#   %onnx::Conv_3200[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3201[FLOAT, 384]
#   %onnx::Conv_3203[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3204[FLOAT, 2304]
#   %onnx::Conv_3206[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3207[FLOAT, 2304]
#   %onnx::Conv_3209[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3210[FLOAT, 384]
#   %onnx::Conv_3212[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3213[FLOAT, 2304]
#   %onnx::Conv_3215[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3216[FLOAT, 2304]
#   %onnx::Conv_3218[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3219[FLOAT, 384]
#   %onnx::Conv_3221[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3222[FLOAT, 2304]
#   %onnx::Conv_3224[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3225[FLOAT, 2304]
#   %onnx::Conv_3227[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3228[FLOAT, 384]
#   %onnx::Conv_3230[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3231[FLOAT, 2304]
#   %onnx::Conv_3233[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3234[FLOAT, 2304]
#   %onnx::Conv_3236[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3237[FLOAT, 384]
#   %onnx::Conv_3239[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3240[FLOAT, 2304]
#   %onnx::Conv_3242[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3243[FLOAT, 2304]
#   %onnx::Conv_3245[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3246[FLOAT, 384]
#   %onnx::Conv_3248[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3249[FLOAT, 2304]
#   %onnx::Conv_3251[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3252[FLOAT, 2304]
#   %onnx::Conv_3254[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3255[FLOAT, 384]
#   %onnx::Conv_3257[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3258[FLOAT, 2304]
#   %onnx::Conv_3260[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3261[FLOAT, 2304]
#   %onnx::Conv_3263[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3264[FLOAT, 384]
#   %onnx::Conv_3266[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3267[FLOAT, 2304]
#   %onnx::Conv_3269[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3270[FLOAT, 2304]
#   %onnx::Conv_3272[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3273[FLOAT, 384]
#   %onnx::Conv_3275[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3276[FLOAT, 2304]
#   %onnx::Conv_3278[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3279[FLOAT, 2304]
#   %onnx::Conv_3281[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3282[FLOAT, 384]
#   %onnx::Conv_3284[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3285[FLOAT, 2304]
#   %onnx::Conv_3287[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3288[FLOAT, 2304]
#   %onnx::Conv_3290[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3291[FLOAT, 384]
#   %onnx::Conv_3293[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3294[FLOAT, 2304]
#   %onnx::Conv_3296[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3297[FLOAT, 2304]
#   %onnx::Conv_3299[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3300[FLOAT, 384]
#   %onnx::Conv_3302[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3303[FLOAT, 2304]
#   %onnx::Conv_3305[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3306[FLOAT, 2304]
#   %onnx::Conv_3308[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3309[FLOAT, 384]
#   %onnx::Conv_3311[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3312[FLOAT, 2304]
#   %onnx::Conv_3314[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3315[FLOAT, 2304]
#   %onnx::Conv_3317[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3318[FLOAT, 384]
#   %onnx::Conv_3320[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3321[FLOAT, 2304]
#   %onnx::Conv_3323[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3324[FLOAT, 2304]
#   %onnx::Conv_3326[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3327[FLOAT, 384]
#   %onnx::Conv_3329[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3330[FLOAT, 2304]
#   %onnx::Conv_3332[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3333[FLOAT, 2304]
#   %onnx::Conv_3335[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3336[FLOAT, 384]
#   %onnx::Conv_3338[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3339[FLOAT, 2304]
#   %onnx::Conv_3341[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3342[FLOAT, 2304]
#   %onnx::Conv_3344[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3345[FLOAT, 384]
#   %onnx::Conv_3347[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3348[FLOAT, 2304]
#   %onnx::Conv_3350[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3351[FLOAT, 2304]
#   %onnx::Conv_3353[FLOAT, 384x2304x1x1]
#   %onnx::Conv_3354[FLOAT, 384]
#   %onnx::Conv_3356[FLOAT, 2304x384x1x1]
#   %onnx::Conv_3357[FLOAT, 2304]
#   %onnx::Conv_3359[FLOAT, 2304x1x3x3]
#   %onnx::Conv_3360[FLOAT, 2304]
#   %onnx::Conv_3362[FLOAT, 640x2304x1x1]
#   %onnx::Conv_3363[FLOAT, 640]
#   %onnx::Conv_3365[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3366[FLOAT, 3840]
#   %onnx::Conv_3368[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3369[FLOAT, 3840]
#   %onnx::Conv_3371[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3372[FLOAT, 640]
#   %onnx::Conv_3374[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3375[FLOAT, 3840]
#   %onnx::Conv_3377[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3378[FLOAT, 3840]
#   %onnx::Conv_3380[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3381[FLOAT, 640]
#   %onnx::Conv_3383[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3384[FLOAT, 3840]
#   %onnx::Conv_3386[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3387[FLOAT, 3840]
#   %onnx::Conv_3389[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3390[FLOAT, 640]
#   %onnx::Conv_3392[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3393[FLOAT, 3840]
#   %onnx::Conv_3395[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3396[FLOAT, 3840]
#   %onnx::Conv_3398[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3399[FLOAT, 640]
#   %onnx::Conv_3401[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3402[FLOAT, 3840]
#   %onnx::Conv_3404[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3405[FLOAT, 3840]
#   %onnx::Conv_3407[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3408[FLOAT, 640]
#   %onnx::Conv_3410[FLOAT, 3840x640x1x1]
#   %onnx::Conv_3411[FLOAT, 3840]
#   %onnx::Conv_3413[FLOAT, 3840x1x3x3]
#   %onnx::Conv_3414[FLOAT, 3840]
#   %onnx::Conv_3416[FLOAT, 640x3840x1x1]
#   %onnx::Conv_3417[FLOAT, 640]
#   %onnx::Conv_3419[FLOAT, 1280x640x1x1]
#   %onnx::Conv_3420[FLOAT, 1280]
# ) {
#   %/features/features.0/features.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%input, %onnx::Conv_2771, %onnx::Conv_2772)
#   %/features/features.0/features.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.0/features.0.0/Conv_output_0)
#   %/features/features.0/features.0.2/Mul_output_0 = Mul(%/features/features.0/features.0.0/Conv_output_0, %/features/features.0/features.0.2/Sigmoid_output_0)
#   %/features/features.1/features.1.0/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.0/features.0.2/Mul_output_0, %onnx::Conv_2774, %onnx::Conv_2775)
#   %/features/features.1/features.1.0/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.1/features.1.0/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/features.1.0/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.1/features.1.0/block/block.0/block.0.0/Conv_output_0, %/features/features.1/features.1.0/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.1/features.1.0/Add_output_0 = Add(%/features/features.1/features.1.0/block/block.0/block.0.2/Mul_output_0, %/features/features.0/features.0.2/Mul_output_0)
#   %/features/features.1/features.1.1/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.1/features.1.0/Add_output_0, %onnx::Conv_2777, %onnx::Conv_2778)
#   %/features/features.1/features.1.1/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.1/features.1.1/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/features.1.1/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.1/features.1.1/block/block.0/block.0.0/Conv_output_0, %/features/features.1/features.1.1/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.1/features.1.1/Add_output_0 = Add(%/features/features.1/features.1.1/block/block.0/block.0.2/Mul_output_0, %/features/features.1/features.1.0/Add_output_0)
#   %/features/features.1/features.1.2/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.1/features.1.1/Add_output_0, %onnx::Conv_2780, %onnx::Conv_2781)
#   %/features/features.1/features.1.2/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.1/features.1.2/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/features.1.2/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.1/features.1.2/block/block.0/block.0.0/Conv_output_0, %/features/features.1/features.1.2/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.1/features.1.2/Add_output_0 = Add(%/features/features.1/features.1.2/block/block.0/block.0.2/Mul_output_0, %/features/features.1/features.1.1/Add_output_0)
#   %/features/features.1/features.1.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.1/features.1.2/Add_output_0, %onnx::Conv_2783, %onnx::Conv_2784)
#   %/features/features.1/features.1.3/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.1/features.1.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/features.1.3/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.1/features.1.3/block/block.0/block.0.0/Conv_output_0, %/features/features.1/features.1.3/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.1/features.1.3/Add_output_0 = Add(%/features/features.1/features.1.3/block/block.0/block.0.2/Mul_output_0, %/features/features.1/features.1.2/Add_output_0)
#   %/features/features.2/features.2.0/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.1/features.1.3/Add_output_0, %onnx::Conv_2786, %onnx::Conv_2787)
#   %/features/features.2/features.2.0/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.0/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.0/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.0/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.0/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.0/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.0/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2789, %onnx::Conv_2790)
#   %/features/features.2/features.2.1/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.0/block/block.1/block.1.0/Conv_output_0, %onnx::Conv_2792, %onnx::Conv_2793)
#   %/features/features.2/features.2.1/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.1/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.1/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.1/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.1/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.1/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.1/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2795, %onnx::Conv_2796)
#   %/features/features.2/features.2.1/Add_output_0 = Add(%/features/features.2/features.2.1/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.0/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.2/features.2.2/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.1/Add_output_0, %onnx::Conv_2798, %onnx::Conv_2799)
#   %/features/features.2/features.2.2/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.2/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.2/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.2/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.2/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.2/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.2/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2801, %onnx::Conv_2802)
#   %/features/features.2/features.2.2/Add_output_0 = Add(%/features/features.2/features.2.2/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.1/Add_output_0)
#   %/features/features.2/features.2.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.2/Add_output_0, %onnx::Conv_2804, %onnx::Conv_2805)
#   %/features/features.2/features.2.3/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.3/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.3/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.3/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.3/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.3/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2807, %onnx::Conv_2808)
#   %/features/features.2/features.2.3/Add_output_0 = Add(%/features/features.2/features.2.3/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.2/Add_output_0)
#   %/features/features.2/features.2.4/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.3/Add_output_0, %onnx::Conv_2810, %onnx::Conv_2811)
#   %/features/features.2/features.2.4/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.4/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.4/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.4/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.4/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.4/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.4/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2813, %onnx::Conv_2814)
#   %/features/features.2/features.2.4/Add_output_0 = Add(%/features/features.2/features.2.4/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.3/Add_output_0)
#   %/features/features.2/features.2.5/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.4/Add_output_0, %onnx::Conv_2816, %onnx::Conv_2817)
#   %/features/features.2/features.2.5/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.5/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.5/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.5/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.5/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.5/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.5/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2819, %onnx::Conv_2820)
#   %/features/features.2/features.2.5/Add_output_0 = Add(%/features/features.2/features.2.5/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.4/Add_output_0)
#   %/features/features.2/features.2.6/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.2/features.2.5/Add_output_0, %onnx::Conv_2822, %onnx::Conv_2823)
#   %/features/features.2/features.2.6/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.2/features.2.6/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/features.2.6/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.2/features.2.6/block/block.0/block.0.0/Conv_output_0, %/features/features.2/features.2.6/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.2/features.2.6/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/features.2.6/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2825, %onnx::Conv_2826)
#   %/features/features.2/features.2.6/Add_output_0 = Add(%/features/features.2/features.2.6/block/block.1/block.1.0/Conv_output_0, %/features/features.2/features.2.5/Add_output_0)
#   %/features/features.3/features.3.0/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.2/features.2.6/Add_output_0, %onnx::Conv_2828, %onnx::Conv_2829)
#   %/features/features.3/features.3.0/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.0/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.0/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.0/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.0/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.0/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.0/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2831, %onnx::Conv_2832)
#   %/features/features.3/features.3.1/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.0/block/block.1/block.1.0/Conv_output_0, %onnx::Conv_2834, %onnx::Conv_2835)
#   %/features/features.3/features.3.1/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.1/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.1/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.1/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.1/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.1/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.1/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2837, %onnx::Conv_2838)
#   %/features/features.3/features.3.1/Add_output_0 = Add(%/features/features.3/features.3.1/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.0/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.3/features.3.2/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.1/Add_output_0, %onnx::Conv_2840, %onnx::Conv_2841)
#   %/features/features.3/features.3.2/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.2/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.2/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.2/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.2/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.2/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.2/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2843, %onnx::Conv_2844)
#   %/features/features.3/features.3.2/Add_output_0 = Add(%/features/features.3/features.3.2/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.1/Add_output_0)
#   %/features/features.3/features.3.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.2/Add_output_0, %onnx::Conv_2846, %onnx::Conv_2847)
#   %/features/features.3/features.3.3/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.3/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.3/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.3/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.3/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.3/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2849, %onnx::Conv_2850)
#   %/features/features.3/features.3.3/Add_output_0 = Add(%/features/features.3/features.3.3/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.2/Add_output_0)
#   %/features/features.3/features.3.4/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.3/Add_output_0, %onnx::Conv_2852, %onnx::Conv_2853)
#   %/features/features.3/features.3.4/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.4/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.4/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.4/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.4/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.4/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.4/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2855, %onnx::Conv_2856)
#   %/features/features.3/features.3.4/Add_output_0 = Add(%/features/features.3/features.3.4/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.3/Add_output_0)
#   %/features/features.3/features.3.5/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.4/Add_output_0, %onnx::Conv_2858, %onnx::Conv_2859)
#   %/features/features.3/features.3.5/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.5/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.5/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.5/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.5/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.5/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.5/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2861, %onnx::Conv_2862)
#   %/features/features.3/features.3.5/Add_output_0 = Add(%/features/features.3/features.3.5/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.4/Add_output_0)
#   %/features/features.3/features.3.6/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/features.3.5/Add_output_0, %onnx::Conv_2864, %onnx::Conv_2865)
#   %/features/features.3/features.3.6/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.3/features.3.6/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/features.3.6/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.3/features.3.6/block/block.0/block.0.0/Conv_output_0, %/features/features.3/features.3.6/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.3/features.3.6/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.6/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2867, %onnx::Conv_2868)
#   %/features/features.3/features.3.6/Add_output_0 = Add(%/features/features.3/features.3.6/block/block.1/block.1.0/Conv_output_0, %/features/features.3/features.3.5/Add_output_0)
#   %/features/features.4/features.4.0/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/features.3.6/Add_output_0, %onnx::Conv_2870, %onnx::Conv_2871)
#   %/features/features.4/features.4.0/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.4/features.4.0/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.4/features.4.0/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.4/features.4.0/block/block.0/block.0.0/Conv_output_0, %/features/features.4/features.4.0/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.4/features.4.0/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 384, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.4/features.4.0/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_2873, %onnx::Conv_2874)
#   %/features/features.4/features.4.0/block/block.1/block.1.2/Sigmoid_output_0 = Sigmoid(%/features/features.4/features.4.0/block/block.1/block.1.0/Conv_output_0)
# ...
#   %/features/features.7/features.7.2/block/block.2/activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.2/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/features.7.2/block/block.2/activation/Mul_output_0 = Mul(%/features/features.7/features.7.2/block/block.2/fc1/Conv_output_0, %/features/features.7/features.7.2/block/block.2/activation/Sigmoid_output_0)
#   %/features/features.7/features.7.2/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.2/block/block.2/activation/Mul_output_0, %features.7.2.block.2.fc2.weight, %features.7.2.block.2.fc2.bias)
#   %/features/features.7/features.7.2/block/block.2/scale_activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.2/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/features.7.2/block/block.2/Mul_output_0 = Mul(%/features/features.7/features.7.2/block/block.2/scale_activation/Sigmoid_output_0, %/features/features.7/features.7.2/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.2/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.2/block/block.2/Mul_output_0, %onnx::Conv_3380, %onnx::Conv_3381)
#   %/features/features.7/features.7.2/Add_output_0 = Add(%/features/features.7/features.7.2/block/block.3/block.3.0/Conv_output_0, %/features/features.7/features.7.1/Add_output_0)
#   %/features/features.7/features.7.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.2/Add_output_0, %onnx::Conv_3383, %onnx::Conv_3384)
#   %/features/features.7/features.7.3/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/features.7.3/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.7/features.7.3/block/block.0/block.0.0/Conv_output_0, %/features/features.7/features.7.3/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.7/features.7.3/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 3840, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.7/features.7.3/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_3386, %onnx::Conv_3387)
#   %/features/features.7/features.7.3/block/block.1/block.1.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.3/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/features.7.3/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.7/features.7.3/block/block.1/block.1.0/Conv_output_0, %/features/features.7/features.7.3/block/block.1/block.1.2/Sigmoid_output_0)
#   %/features/features.7/features.7.3/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.7/features.7.3/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.3/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.3/block/block.2/avgpool/GlobalAveragePool_output_0, %features.7.3.block.2.fc1.weight, %features.7.3.block.2.fc1.bias)
#   %/features/features.7/features.7.3/block/block.2/activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.3/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/features.7.3/block/block.2/activation/Mul_output_0 = Mul(%/features/features.7/features.7.3/block/block.2/fc1/Conv_output_0, %/features/features.7/features.7.3/block/block.2/activation/Sigmoid_output_0)
#   %/features/features.7/features.7.3/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.3/block/block.2/activation/Mul_output_0, %features.7.3.block.2.fc2.weight, %features.7.3.block.2.fc2.bias)
#   %/features/features.7/features.7.3/block/block.2/scale_activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.3/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/features.7.3/block/block.2/Mul_output_0 = Mul(%/features/features.7/features.7.3/block/block.2/scale_activation/Sigmoid_output_0, %/features/features.7/features.7.3/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.3/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.3/block/block.2/Mul_output_0, %onnx::Conv_3389, %onnx::Conv_3390)
#   %/features/features.7/features.7.3/Add_output_0 = Add(%/features/features.7/features.7.3/block/block.3/block.3.0/Conv_output_0, %/features/features.7/features.7.2/Add_output_0)
#   %/features/features.7/features.7.4/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.3/Add_output_0, %onnx::Conv_3392, %onnx::Conv_3393)
#   %/features/features.7/features.7.4/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.4/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/features.7.4/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.7/features.7.4/block/block.0/block.0.0/Conv_output_0, %/features/features.7/features.7.4/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.7/features.7.4/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 3840, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.7/features.7.4/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_3395, %onnx::Conv_3396)
#   %/features/features.7/features.7.4/block/block.1/block.1.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.4/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/features.7.4/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.7/features.7.4/block/block.1/block.1.0/Conv_output_0, %/features/features.7/features.7.4/block/block.1/block.1.2/Sigmoid_output_0)
#   %/features/features.7/features.7.4/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.7/features.7.4/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.4/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.4/block/block.2/avgpool/GlobalAveragePool_output_0, %features.7.4.block.2.fc1.weight, %features.7.4.block.2.fc1.bias)
#   %/features/features.7/features.7.4/block/block.2/activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.4/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/features.7.4/block/block.2/activation/Mul_output_0 = Mul(%/features/features.7/features.7.4/block/block.2/fc1/Conv_output_0, %/features/features.7/features.7.4/block/block.2/activation/Sigmoid_output_0)
#   %/features/features.7/features.7.4/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.4/block/block.2/activation/Mul_output_0, %features.7.4.block.2.fc2.weight, %features.7.4.block.2.fc2.bias)
#   %/features/features.7/features.7.4/block/block.2/scale_activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.4/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/features.7.4/block/block.2/Mul_output_0 = Mul(%/features/features.7/features.7.4/block/block.2/scale_activation/Sigmoid_output_0, %/features/features.7/features.7.4/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.4/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.4/block/block.2/Mul_output_0, %onnx::Conv_3398, %onnx::Conv_3399)
#   %/features/features.7/features.7.4/Add_output_0 = Add(%/features/features.7/features.7.4/block/block.3/block.3.0/Conv_output_0, %/features/features.7/features.7.3/Add_output_0)
#   %/features/features.7/features.7.5/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.4/Add_output_0, %onnx::Conv_3401, %onnx::Conv_3402)
#   %/features/features.7/features.7.5/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.5/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/features.7.5/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.7/features.7.5/block/block.0/block.0.0/Conv_output_0, %/features/features.7/features.7.5/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.7/features.7.5/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 3840, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.7/features.7.5/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_3404, %onnx::Conv_3405)
#   %/features/features.7/features.7.5/block/block.1/block.1.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.5/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/features.7.5/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.7/features.7.5/block/block.1/block.1.0/Conv_output_0, %/features/features.7/features.7.5/block/block.1/block.1.2/Sigmoid_output_0)
#   %/features/features.7/features.7.5/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.7/features.7.5/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.5/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.5/block/block.2/avgpool/GlobalAveragePool_output_0, %features.7.5.block.2.fc1.weight, %features.7.5.block.2.fc1.bias)
#   %/features/features.7/features.7.5/block/block.2/activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.5/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/features.7.5/block/block.2/activation/Mul_output_0 = Mul(%/features/features.7/features.7.5/block/block.2/fc1/Conv_output_0, %/features/features.7/features.7.5/block/block.2/activation/Sigmoid_output_0)
#   %/features/features.7/features.7.5/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.5/block/block.2/activation/Mul_output_0, %features.7.5.block.2.fc2.weight, %features.7.5.block.2.fc2.bias)
#   %/features/features.7/features.7.5/block/block.2/scale_activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.5/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/features.7.5/block/block.2/Mul_output_0 = Mul(%/features/features.7/features.7.5/block/block.2/scale_activation/Sigmoid_output_0, %/features/features.7/features.7.5/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.5/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.5/block/block.2/Mul_output_0, %onnx::Conv_3407, %onnx::Conv_3408)
#   %/features/features.7/features.7.5/Add_output_0 = Add(%/features/features.7/features.7.5/block/block.3/block.3.0/Conv_output_0, %/features/features.7/features.7.4/Add_output_0)
#   %/features/features.7/features.7.6/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.5/Add_output_0, %onnx::Conv_3410, %onnx::Conv_3411)
#   %/features/features.7/features.7.6/block/block.0/block.0.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.6/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/features.7.6/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.7/features.7.6/block/block.0/block.0.0/Conv_output_0, %/features/features.7/features.7.6/block/block.0/block.0.2/Sigmoid_output_0)
#   %/features/features.7/features.7.6/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 3840, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.7/features.7.6/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_3413, %onnx::Conv_3414)
#   %/features/features.7/features.7.6/block/block.1/block.1.2/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.6/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/features.7.6/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.7/features.7.6/block/block.1/block.1.0/Conv_output_0, %/features/features.7/features.7.6/block/block.1/block.1.2/Sigmoid_output_0)
#   %/features/features.7/features.7.6/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.7/features.7.6/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.6/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.6/block/block.2/avgpool/GlobalAveragePool_output_0, %features.7.6.block.2.fc1.weight, %features.7.6.block.2.fc1.bias)
#   %/features/features.7/features.7.6/block/block.2/activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.6/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/features.7.6/block/block.2/activation/Mul_output_0 = Mul(%/features/features.7/features.7.6/block/block.2/fc1/Conv_output_0, %/features/features.7/features.7.6/block/block.2/activation/Sigmoid_output_0)
#   %/features/features.7/features.7.6/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.6/block/block.2/activation/Mul_output_0, %features.7.6.block.2.fc2.weight, %features.7.6.block.2.fc2.bias)
#   %/features/features.7/features.7.6/block/block.2/scale_activation/Sigmoid_output_0 = Sigmoid(%/features/features.7/features.7.6/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/features.7.6/block/block.2/Mul_output_0 = Mul(%/features/features.7/features.7.6/block/block.2/scale_activation/Sigmoid_output_0, %/features/features.7/features.7.6/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.7/features.7.6/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.6/block/block.2/Mul_output_0, %onnx::Conv_3416, %onnx::Conv_3417)
#   %/features/features.7/features.7.6/Add_output_0 = Add(%/features/features.7/features.7.6/block/block.3/block.3.0/Conv_output_0, %/features/features.7/features.7.5/Add_output_0)
#   %/features/features.8/features.8.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/features.7.6/Add_output_0, %onnx::Conv_3419, %onnx::Conv_3420)
#   %/features/features.8/features.8.2/Sigmoid_output_0 = Sigmoid(%/features/features.8/features.8.0/Conv_output_0)
#   %/features/features.8/features.8.2/Mul_output_0 = Mul(%/features/features.8/features.8.0/Conv_output_0, %/features/features.8/features.8.2/Sigmoid_output_0)
#   %/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.8/features.8.2/Mul_output_0)
#   %/Flatten_output_0 = Flatten[axis = 1](%/avgpool/GlobalAveragePool_output_0)
#   %output = Gemm[alpha = 1, beta = 1, transB = 1](%/Flatten_output_0, %classifier.1.weight, %classifier.1.bias)
#   return %output
# }

# %%
try:
    onnx.checker.check_model(model)
    print("모델 검증 성공")
except onnx.checker.ValidationError as e:
    print("모델 검증 실패")
    print(e)
# Out:
# 모델 검증 성공

# %%
# 모델 시각화
netron.start (ONNX_PATH)
# Out:
# Serving './onnx/efficientnet_v2_l.onnx' at http://localhost:8080
# ('localhost', 8080)
