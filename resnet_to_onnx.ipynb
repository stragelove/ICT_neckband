# %%
import torch
import onnx
import onnxruntime as ort
import netron

# %%
print(torch.__version__)
print(onnx.__version__)
print(ort.get_device())
print(ort.__version__)
# Out:
# 2.7.0+cu126
# 1.18.0
# GPU
# 1.22.0

# %%
MODEL_PATH = "./result/resnet152_best.pt"
ONNX_PATH = "./onnx/resnet152.onnx"
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda

# %%
model = torch.load(MODEL_PATH, map_location=DEVICE, weights_only=False)
model.to(DEVICE)
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=5, bias=True)
# )

# %%
# 더미 생성: (batch, 1, mel_bins, time)
dummy = torch.randn(1, 1, 64, 101, device=DEVICE)

# %%
# onnx 모델 변환
print("ONNX 변환중...")

torch.onnx.export(model, # PyTorch 모델
                dummy, # 입력 텐서 (튜플도 가능)
                ONNX_PATH, # 저장할 파일 경로
                export_params=True, # 모델 파라미터 포함
                opset_version=11, # onnx의 연산자 버전
                input_names=['input'], # 입력 이름
                output_names=['output'], # 출력 이름
                dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}} # 배치 크기를 동적으로 지정
)

print(f"ONNX 변환완료'{ONNX_PATH}'에 저장됨")
# Out:
# ONNX 변환중...
# ONNX 변환완료'./onnx/resnet152.onnx'에 저장됨

# %%
model = onnx.load(ONNX_PATH)
print(onnx.helper.printable_graph(model.graph))
# Out:
# graph main_graph (
#   %input[FLOAT, batch_sizex1x64x101]
# ) initializers (
#   %fc.weight[FLOAT, 5x2048]
#   %fc.bias[FLOAT, 5]
#   %onnx::Conv_1449[FLOAT, 64x1x7x7]
#   %onnx::Conv_1450[FLOAT, 64]
#   %onnx::Conv_1452[FLOAT, 64x64x1x1]
#   %onnx::Conv_1453[FLOAT, 64]
#   %onnx::Conv_1455[FLOAT, 64x64x3x3]
#   %onnx::Conv_1456[FLOAT, 64]
#   %onnx::Conv_1458[FLOAT, 256x64x1x1]
#   %onnx::Conv_1459[FLOAT, 256]
#   %onnx::Conv_1461[FLOAT, 256x64x1x1]
#   %onnx::Conv_1462[FLOAT, 256]
#   %onnx::Conv_1464[FLOAT, 64x256x1x1]
#   %onnx::Conv_1465[FLOAT, 64]
#   %onnx::Conv_1467[FLOAT, 64x64x3x3]
#   %onnx::Conv_1468[FLOAT, 64]
#   %onnx::Conv_1470[FLOAT, 256x64x1x1]
#   %onnx::Conv_1471[FLOAT, 256]
#   %onnx::Conv_1473[FLOAT, 64x256x1x1]
#   %onnx::Conv_1474[FLOAT, 64]
#   %onnx::Conv_1476[FLOAT, 64x64x3x3]
#   %onnx::Conv_1477[FLOAT, 64]
#   %onnx::Conv_1479[FLOAT, 256x64x1x1]
#   %onnx::Conv_1480[FLOAT, 256]
#   %onnx::Conv_1482[FLOAT, 128x256x1x1]
#   %onnx::Conv_1483[FLOAT, 128]
#   %onnx::Conv_1485[FLOAT, 128x128x3x3]
#   %onnx::Conv_1486[FLOAT, 128]
#   %onnx::Conv_1488[FLOAT, 512x128x1x1]
#   %onnx::Conv_1489[FLOAT, 512]
#   %onnx::Conv_1491[FLOAT, 512x256x1x1]
#   %onnx::Conv_1492[FLOAT, 512]
#   %onnx::Conv_1494[FLOAT, 128x512x1x1]
#   %onnx::Conv_1495[FLOAT, 128]
#   %onnx::Conv_1497[FLOAT, 128x128x3x3]
#   %onnx::Conv_1498[FLOAT, 128]
#   %onnx::Conv_1500[FLOAT, 512x128x1x1]
#   %onnx::Conv_1501[FLOAT, 512]
#   %onnx::Conv_1503[FLOAT, 128x512x1x1]
#   %onnx::Conv_1504[FLOAT, 128]
#   %onnx::Conv_1506[FLOAT, 128x128x3x3]
#   %onnx::Conv_1507[FLOAT, 128]
#   %onnx::Conv_1509[FLOAT, 512x128x1x1]
#   %onnx::Conv_1510[FLOAT, 512]
#   %onnx::Conv_1512[FLOAT, 128x512x1x1]
#   %onnx::Conv_1513[FLOAT, 128]
#   %onnx::Conv_1515[FLOAT, 128x128x3x3]
#   %onnx::Conv_1516[FLOAT, 128]
#   %onnx::Conv_1518[FLOAT, 512x128x1x1]
#   %onnx::Conv_1519[FLOAT, 512]
#   %onnx::Conv_1521[FLOAT, 128x512x1x1]
#   %onnx::Conv_1522[FLOAT, 128]
#   %onnx::Conv_1524[FLOAT, 128x128x3x3]
#   %onnx::Conv_1525[FLOAT, 128]
#   %onnx::Conv_1527[FLOAT, 512x128x1x1]
#   %onnx::Conv_1528[FLOAT, 512]
#   %onnx::Conv_1530[FLOAT, 128x512x1x1]
#   %onnx::Conv_1531[FLOAT, 128]
#   %onnx::Conv_1533[FLOAT, 128x128x3x3]
#   %onnx::Conv_1534[FLOAT, 128]
#   %onnx::Conv_1536[FLOAT, 512x128x1x1]
#   %onnx::Conv_1537[FLOAT, 512]
#   %onnx::Conv_1539[FLOAT, 128x512x1x1]
#   %onnx::Conv_1540[FLOAT, 128]
#   %onnx::Conv_1542[FLOAT, 128x128x3x3]
#   %onnx::Conv_1543[FLOAT, 128]
#   %onnx::Conv_1545[FLOAT, 512x128x1x1]
#   %onnx::Conv_1546[FLOAT, 512]
#   %onnx::Conv_1548[FLOAT, 128x512x1x1]
#   %onnx::Conv_1549[FLOAT, 128]
#   %onnx::Conv_1551[FLOAT, 128x128x3x3]
#   %onnx::Conv_1552[FLOAT, 128]
#   %onnx::Conv_1554[FLOAT, 512x128x1x1]
#   %onnx::Conv_1555[FLOAT, 512]
#   %onnx::Conv_1557[FLOAT, 256x512x1x1]
#   %onnx::Conv_1558[FLOAT, 256]
#   %onnx::Conv_1560[FLOAT, 256x256x3x3]
#   %onnx::Conv_1561[FLOAT, 256]
#   %onnx::Conv_1563[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1564[FLOAT, 1024]
#   %onnx::Conv_1566[FLOAT, 1024x512x1x1]
#   %onnx::Conv_1567[FLOAT, 1024]
#   %onnx::Conv_1569[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1570[FLOAT, 256]
#   %onnx::Conv_1572[FLOAT, 256x256x3x3]
#   %onnx::Conv_1573[FLOAT, 256]
#   %onnx::Conv_1575[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1576[FLOAT, 1024]
#   %onnx::Conv_1578[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1579[FLOAT, 256]
#   %onnx::Conv_1581[FLOAT, 256x256x3x3]
#   %onnx::Conv_1582[FLOAT, 256]
#   %onnx::Conv_1584[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1585[FLOAT, 1024]
#   %onnx::Conv_1587[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1588[FLOAT, 256]
#   %onnx::Conv_1590[FLOAT, 256x256x3x3]
#   %onnx::Conv_1591[FLOAT, 256]
#   %onnx::Conv_1593[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1594[FLOAT, 1024]
#   %onnx::Conv_1596[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1597[FLOAT, 256]
#   %onnx::Conv_1599[FLOAT, 256x256x3x3]
#   %onnx::Conv_1600[FLOAT, 256]
#   %onnx::Conv_1602[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1603[FLOAT, 1024]
#   %onnx::Conv_1605[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1606[FLOAT, 256]
#   %onnx::Conv_1608[FLOAT, 256x256x3x3]
#   %onnx::Conv_1609[FLOAT, 256]
#   %onnx::Conv_1611[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1612[FLOAT, 1024]
#   %onnx::Conv_1614[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1615[FLOAT, 256]
#   %onnx::Conv_1617[FLOAT, 256x256x3x3]
#   %onnx::Conv_1618[FLOAT, 256]
#   %onnx::Conv_1620[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1621[FLOAT, 1024]
#   %onnx::Conv_1623[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1624[FLOAT, 256]
#   %onnx::Conv_1626[FLOAT, 256x256x3x3]
#   %onnx::Conv_1627[FLOAT, 256]
#   %onnx::Conv_1629[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1630[FLOAT, 1024]
#   %onnx::Conv_1632[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1633[FLOAT, 256]
#   %onnx::Conv_1635[FLOAT, 256x256x3x3]
#   %onnx::Conv_1636[FLOAT, 256]
#   %onnx::Conv_1638[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1639[FLOAT, 1024]
#   %onnx::Conv_1641[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1642[FLOAT, 256]
#   %onnx::Conv_1644[FLOAT, 256x256x3x3]
#   %onnx::Conv_1645[FLOAT, 256]
#   %onnx::Conv_1647[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1648[FLOAT, 1024]
#   %onnx::Conv_1650[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1651[FLOAT, 256]
#   %onnx::Conv_1653[FLOAT, 256x256x3x3]
#   %onnx::Conv_1654[FLOAT, 256]
#   %onnx::Conv_1656[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1657[FLOAT, 1024]
#   %onnx::Conv_1659[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1660[FLOAT, 256]
#   %onnx::Conv_1662[FLOAT, 256x256x3x3]
#   %onnx::Conv_1663[FLOAT, 256]
#   %onnx::Conv_1665[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1666[FLOAT, 1024]
#   %onnx::Conv_1668[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1669[FLOAT, 256]
#   %onnx::Conv_1671[FLOAT, 256x256x3x3]
#   %onnx::Conv_1672[FLOAT, 256]
#   %onnx::Conv_1674[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1675[FLOAT, 1024]
#   %onnx::Conv_1677[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1678[FLOAT, 256]
#   %onnx::Conv_1680[FLOAT, 256x256x3x3]
#   %onnx::Conv_1681[FLOAT, 256]
#   %onnx::Conv_1683[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1684[FLOAT, 1024]
#   %onnx::Conv_1686[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1687[FLOAT, 256]
#   %onnx::Conv_1689[FLOAT, 256x256x3x3]
#   %onnx::Conv_1690[FLOAT, 256]
#   %onnx::Conv_1692[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1693[FLOAT, 1024]
#   %onnx::Conv_1695[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1696[FLOAT, 256]
#   %onnx::Conv_1698[FLOAT, 256x256x3x3]
#   %onnx::Conv_1699[FLOAT, 256]
#   %onnx::Conv_1701[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1702[FLOAT, 1024]
#   %onnx::Conv_1704[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1705[FLOAT, 256]
#   %onnx::Conv_1707[FLOAT, 256x256x3x3]
#   %onnx::Conv_1708[FLOAT, 256]
#   %onnx::Conv_1710[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1711[FLOAT, 1024]
#   %onnx::Conv_1713[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1714[FLOAT, 256]
#   %onnx::Conv_1716[FLOAT, 256x256x3x3]
#   %onnx::Conv_1717[FLOAT, 256]
#   %onnx::Conv_1719[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1720[FLOAT, 1024]
#   %onnx::Conv_1722[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1723[FLOAT, 256]
#   %onnx::Conv_1725[FLOAT, 256x256x3x3]
#   %onnx::Conv_1726[FLOAT, 256]
#   %onnx::Conv_1728[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1729[FLOAT, 1024]
#   %onnx::Conv_1731[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1732[FLOAT, 256]
#   %onnx::Conv_1734[FLOAT, 256x256x3x3]
#   %onnx::Conv_1735[FLOAT, 256]
#   %onnx::Conv_1737[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1738[FLOAT, 1024]
#   %onnx::Conv_1740[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1741[FLOAT, 256]
#   %onnx::Conv_1743[FLOAT, 256x256x3x3]
#   %onnx::Conv_1744[FLOAT, 256]
#   %onnx::Conv_1746[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1747[FLOAT, 1024]
#   %onnx::Conv_1749[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1750[FLOAT, 256]
#   %onnx::Conv_1752[FLOAT, 256x256x3x3]
#   %onnx::Conv_1753[FLOAT, 256]
#   %onnx::Conv_1755[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1756[FLOAT, 1024]
#   %onnx::Conv_1758[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1759[FLOAT, 256]
#   %onnx::Conv_1761[FLOAT, 256x256x3x3]
#   %onnx::Conv_1762[FLOAT, 256]
#   %onnx::Conv_1764[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1765[FLOAT, 1024]
#   %onnx::Conv_1767[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1768[FLOAT, 256]
#   %onnx::Conv_1770[FLOAT, 256x256x3x3]
#   %onnx::Conv_1771[FLOAT, 256]
#   %onnx::Conv_1773[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1774[FLOAT, 1024]
#   %onnx::Conv_1776[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1777[FLOAT, 256]
#   %onnx::Conv_1779[FLOAT, 256x256x3x3]
#   %onnx::Conv_1780[FLOAT, 256]
#   %onnx::Conv_1782[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1783[FLOAT, 1024]
#   %onnx::Conv_1785[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1786[FLOAT, 256]
#   %onnx::Conv_1788[FLOAT, 256x256x3x3]
#   %onnx::Conv_1789[FLOAT, 256]
#   %onnx::Conv_1791[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1792[FLOAT, 1024]
#   %onnx::Conv_1794[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1795[FLOAT, 256]
#   %onnx::Conv_1797[FLOAT, 256x256x3x3]
#   %onnx::Conv_1798[FLOAT, 256]
#   %onnx::Conv_1800[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1801[FLOAT, 1024]
#   %onnx::Conv_1803[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1804[FLOAT, 256]
#   %onnx::Conv_1806[FLOAT, 256x256x3x3]
#   %onnx::Conv_1807[FLOAT, 256]
#   %onnx::Conv_1809[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1810[FLOAT, 1024]
#   %onnx::Conv_1812[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1813[FLOAT, 256]
#   %onnx::Conv_1815[FLOAT, 256x256x3x3]
#   %onnx::Conv_1816[FLOAT, 256]
#   %onnx::Conv_1818[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1819[FLOAT, 1024]
#   %onnx::Conv_1821[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1822[FLOAT, 256]
#   %onnx::Conv_1824[FLOAT, 256x256x3x3]
#   %onnx::Conv_1825[FLOAT, 256]
#   %onnx::Conv_1827[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1828[FLOAT, 1024]
#   %onnx::Conv_1830[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1831[FLOAT, 256]
#   %onnx::Conv_1833[FLOAT, 256x256x3x3]
#   %onnx::Conv_1834[FLOAT, 256]
#   %onnx::Conv_1836[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1837[FLOAT, 1024]
#   %onnx::Conv_1839[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1840[FLOAT, 256]
#   %onnx::Conv_1842[FLOAT, 256x256x3x3]
#   %onnx::Conv_1843[FLOAT, 256]
#   %onnx::Conv_1845[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1846[FLOAT, 1024]
#   %onnx::Conv_1848[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1849[FLOAT, 256]
#   %onnx::Conv_1851[FLOAT, 256x256x3x3]
#   %onnx::Conv_1852[FLOAT, 256]
#   %onnx::Conv_1854[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1855[FLOAT, 1024]
#   %onnx::Conv_1857[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1858[FLOAT, 256]
#   %onnx::Conv_1860[FLOAT, 256x256x3x3]
#   %onnx::Conv_1861[FLOAT, 256]
#   %onnx::Conv_1863[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1864[FLOAT, 1024]
#   %onnx::Conv_1866[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1867[FLOAT, 256]
#   %onnx::Conv_1869[FLOAT, 256x256x3x3]
#   %onnx::Conv_1870[FLOAT, 256]
#   %onnx::Conv_1872[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1873[FLOAT, 1024]
#   %onnx::Conv_1875[FLOAT, 256x1024x1x1]
#   %onnx::Conv_1876[FLOAT, 256]
#   %onnx::Conv_1878[FLOAT, 256x256x3x3]
#   %onnx::Conv_1879[FLOAT, 256]
#   %onnx::Conv_1881[FLOAT, 1024x256x1x1]
#   %onnx::Conv_1882[FLOAT, 1024]
#   %onnx::Conv_1884[FLOAT, 512x1024x1x1]
#   %onnx::Conv_1885[FLOAT, 512]
#   %onnx::Conv_1887[FLOAT, 512x512x3x3]
#   %onnx::Conv_1888[FLOAT, 512]
#   %onnx::Conv_1890[FLOAT, 2048x512x1x1]
#   %onnx::Conv_1891[FLOAT, 2048]
#   %onnx::Conv_1893[FLOAT, 2048x1024x1x1]
#   %onnx::Conv_1894[FLOAT, 2048]
#   %onnx::Conv_1896[FLOAT, 512x2048x1x1]
#   %onnx::Conv_1897[FLOAT, 512]
#   %onnx::Conv_1899[FLOAT, 512x512x3x3]
#   %onnx::Conv_1900[FLOAT, 512]
#   %onnx::Conv_1902[FLOAT, 2048x512x1x1]
#   %onnx::Conv_1903[FLOAT, 2048]
#   %onnx::Conv_1905[FLOAT, 512x2048x1x1]
#   %onnx::Conv_1906[FLOAT, 512]
#   %onnx::Conv_1908[FLOAT, 512x512x3x3]
#   %onnx::Conv_1909[FLOAT, 512]
#   %onnx::Conv_1911[FLOAT, 2048x512x1x1]
#   %onnx::Conv_1912[FLOAT, 2048]
# ) {
#   %/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [7, 7], pads = [3, 3, 3, 3], strides = [2, 2]](%input, %onnx::Conv_1449, %onnx::Conv_1450)
#   %/relu/Relu_output_0 = Relu(%/conv1/Conv_output_0)
#   %/maxpool/MaxPool_output_0 = MaxPool[ceil_mode = 0, dilations = [1, 1], kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/relu/Relu_output_0)
#   %/layer1/layer1.0/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/maxpool/MaxPool_output_0, %onnx::Conv_1452, %onnx::Conv_1453)
#   %/layer1/layer1.0/relu/Relu_output_0 = Relu(%/layer1/layer1.0/conv1/Conv_output_0)
#   %/layer1/layer1.0/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer1/layer1.0/relu/Relu_output_0, %onnx::Conv_1455, %onnx::Conv_1456)
#   %/layer1/layer1.0/relu_1/Relu_output_0 = Relu(%/layer1/layer1.0/conv2/Conv_output_0)
#   %/layer1/layer1.0/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.0/relu_1/Relu_output_0, %onnx::Conv_1458, %onnx::Conv_1459)
#   %/layer1/layer1.0/downsample/downsample.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/maxpool/MaxPool_output_0, %onnx::Conv_1461, %onnx::Conv_1462)
#   %/layer1/layer1.0/Add_output_0 = Add(%/layer1/layer1.0/conv3/Conv_output_0, %/layer1/layer1.0/downsample/downsample.0/Conv_output_0)
#   %/layer1/layer1.0/relu_2/Relu_output_0 = Relu(%/layer1/layer1.0/Add_output_0)
#   %/layer1/layer1.1/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.0/relu_2/Relu_output_0, %onnx::Conv_1464, %onnx::Conv_1465)
#   %/layer1/layer1.1/relu/Relu_output_0 = Relu(%/layer1/layer1.1/conv1/Conv_output_0)
#   %/layer1/layer1.1/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer1/layer1.1/relu/Relu_output_0, %onnx::Conv_1467, %onnx::Conv_1468)
#   %/layer1/layer1.1/relu_1/Relu_output_0 = Relu(%/layer1/layer1.1/conv2/Conv_output_0)
#   %/layer1/layer1.1/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.1/relu_1/Relu_output_0, %onnx::Conv_1470, %onnx::Conv_1471)
#   %/layer1/layer1.1/Add_output_0 = Add(%/layer1/layer1.1/conv3/Conv_output_0, %/layer1/layer1.0/relu_2/Relu_output_0)
#   %/layer1/layer1.1/relu_2/Relu_output_0 = Relu(%/layer1/layer1.1/Add_output_0)
#   %/layer1/layer1.2/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.1/relu_2/Relu_output_0, %onnx::Conv_1473, %onnx::Conv_1474)
#   %/layer1/layer1.2/relu/Relu_output_0 = Relu(%/layer1/layer1.2/conv1/Conv_output_0)
#   %/layer1/layer1.2/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer1/layer1.2/relu/Relu_output_0, %onnx::Conv_1476, %onnx::Conv_1477)
#   %/layer1/layer1.2/relu_1/Relu_output_0 = Relu(%/layer1/layer1.2/conv2/Conv_output_0)
#   %/layer1/layer1.2/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.2/relu_1/Relu_output_0, %onnx::Conv_1479, %onnx::Conv_1480)
#   %/layer1/layer1.2/Add_output_0 = Add(%/layer1/layer1.2/conv3/Conv_output_0, %/layer1/layer1.1/relu_2/Relu_output_0)
#   %/layer1/layer1.2/relu_2/Relu_output_0 = Relu(%/layer1/layer1.2/Add_output_0)
#   %/layer2/layer2.0/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer1/layer1.2/relu_2/Relu_output_0, %onnx::Conv_1482, %onnx::Conv_1483)
#   %/layer2/layer2.0/relu/Relu_output_0 = Relu(%/layer2/layer2.0/conv1/Conv_output_0)
#   %/layer2/layer2.0/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/layer2/layer2.0/relu/Relu_output_0, %onnx::Conv_1485, %onnx::Conv_1486)
#   %/layer2/layer2.0/relu_1/Relu_output_0 = Relu(%/layer2/layer2.0/conv2/Conv_output_0)
#   %/layer2/layer2.0/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.0/relu_1/Relu_output_0, %onnx::Conv_1488, %onnx::Conv_1489)
#   %/layer2/layer2.0/downsample/downsample.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%/layer1/layer1.2/relu_2/Relu_output_0, %onnx::Conv_1491, %onnx::Conv_1492)
#   %/layer2/layer2.0/Add_output_0 = Add(%/layer2/layer2.0/conv3/Conv_output_0, %/layer2/layer2.0/downsample/downsample.0/Conv_output_0)
#   %/layer2/layer2.0/relu_2/Relu_output_0 = Relu(%/layer2/layer2.0/Add_output_0)
#   %/layer2/layer2.1/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.0/relu_2/Relu_output_0, %onnx::Conv_1494, %onnx::Conv_1495)
#   %/layer2/layer2.1/relu/Relu_output_0 = Relu(%/layer2/layer2.1/conv1/Conv_output_0)
#   %/layer2/layer2.1/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.1/relu/Relu_output_0, %onnx::Conv_1497, %onnx::Conv_1498)
#   %/layer2/layer2.1/relu_1/Relu_output_0 = Relu(%/layer2/layer2.1/conv2/Conv_output_0)
#   %/layer2/layer2.1/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.1/relu_1/Relu_output_0, %onnx::Conv_1500, %onnx::Conv_1501)
#   %/layer2/layer2.1/Add_output_0 = Add(%/layer2/layer2.1/conv3/Conv_output_0, %/layer2/layer2.0/relu_2/Relu_output_0)
#   %/layer2/layer2.1/relu_2/Relu_output_0 = Relu(%/layer2/layer2.1/Add_output_0)
#   %/layer2/layer2.2/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.1/relu_2/Relu_output_0, %onnx::Conv_1503, %onnx::Conv_1504)
#   %/layer2/layer2.2/relu/Relu_output_0 = Relu(%/layer2/layer2.2/conv1/Conv_output_0)
#   %/layer2/layer2.2/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.2/relu/Relu_output_0, %onnx::Conv_1506, %onnx::Conv_1507)
#   %/layer2/layer2.2/relu_1/Relu_output_0 = Relu(%/layer2/layer2.2/conv2/Conv_output_0)
#   %/layer2/layer2.2/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.2/relu_1/Relu_output_0, %onnx::Conv_1509, %onnx::Conv_1510)
#   %/layer2/layer2.2/Add_output_0 = Add(%/layer2/layer2.2/conv3/Conv_output_0, %/layer2/layer2.1/relu_2/Relu_output_0)
#   %/layer2/layer2.2/relu_2/Relu_output_0 = Relu(%/layer2/layer2.2/Add_output_0)
#   %/layer2/layer2.3/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.2/relu_2/Relu_output_0, %onnx::Conv_1512, %onnx::Conv_1513)
#   %/layer2/layer2.3/relu/Relu_output_0 = Relu(%/layer2/layer2.3/conv1/Conv_output_0)
#   %/layer2/layer2.3/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.3/relu/Relu_output_0, %onnx::Conv_1515, %onnx::Conv_1516)
#   %/layer2/layer2.3/relu_1/Relu_output_0 = Relu(%/layer2/layer2.3/conv2/Conv_output_0)
#   %/layer2/layer2.3/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.3/relu_1/Relu_output_0, %onnx::Conv_1518, %onnx::Conv_1519)
#   %/layer2/layer2.3/Add_output_0 = Add(%/layer2/layer2.3/conv3/Conv_output_0, %/layer2/layer2.2/relu_2/Relu_output_0)
#   %/layer2/layer2.3/relu_2/Relu_output_0 = Relu(%/layer2/layer2.3/Add_output_0)
#   %/layer2/layer2.4/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.3/relu_2/Relu_output_0, %onnx::Conv_1521, %onnx::Conv_1522)
#   %/layer2/layer2.4/relu/Relu_output_0 = Relu(%/layer2/layer2.4/conv1/Conv_output_0)
#   %/layer2/layer2.4/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.4/relu/Relu_output_0, %onnx::Conv_1524, %onnx::Conv_1525)
#   %/layer2/layer2.4/relu_1/Relu_output_0 = Relu(%/layer2/layer2.4/conv2/Conv_output_0)
#   %/layer2/layer2.4/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.4/relu_1/Relu_output_0, %onnx::Conv_1527, %onnx::Conv_1528)
#   %/layer2/layer2.4/Add_output_0 = Add(%/layer2/layer2.4/conv3/Conv_output_0, %/layer2/layer2.3/relu_2/Relu_output_0)
#   %/layer2/layer2.4/relu_2/Relu_output_0 = Relu(%/layer2/layer2.4/Add_output_0)
#   %/layer2/layer2.5/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.4/relu_2/Relu_output_0, %onnx::Conv_1530, %onnx::Conv_1531)
#   %/layer2/layer2.5/relu/Relu_output_0 = Relu(%/layer2/layer2.5/conv1/Conv_output_0)
#   %/layer2/layer2.5/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.5/relu/Relu_output_0, %onnx::Conv_1533, %onnx::Conv_1534)
#   %/layer2/layer2.5/relu_1/Relu_output_0 = Relu(%/layer2/layer2.5/conv2/Conv_output_0)
#   %/layer2/layer2.5/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.5/relu_1/Relu_output_0, %onnx::Conv_1536, %onnx::Conv_1537)
#   %/layer2/layer2.5/Add_output_0 = Add(%/layer2/layer2.5/conv3/Conv_output_0, %/layer2/layer2.4/relu_2/Relu_output_0)
#   %/layer2/layer2.5/relu_2/Relu_output_0 = Relu(%/layer2/layer2.5/Add_output_0)
#   %/layer2/layer2.6/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.5/relu_2/Relu_output_0, %onnx::Conv_1539, %onnx::Conv_1540)
#   %/layer2/layer2.6/relu/Relu_output_0 = Relu(%/layer2/layer2.6/conv1/Conv_output_0)
#   %/layer2/layer2.6/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.6/relu/Relu_output_0, %onnx::Conv_1542, %onnx::Conv_1543)
#   %/layer2/layer2.6/relu_1/Relu_output_0 = Relu(%/layer2/layer2.6/conv2/Conv_output_0)
#   %/layer2/layer2.6/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.6/relu_1/Relu_output_0, %onnx::Conv_1545, %onnx::Conv_1546)
#   %/layer2/layer2.6/Add_output_0 = Add(%/layer2/layer2.6/conv3/Conv_output_0, %/layer2/layer2.5/relu_2/Relu_output_0)
#   %/layer2/layer2.6/relu_2/Relu_output_0 = Relu(%/layer2/layer2.6/Add_output_0)
#   %/layer2/layer2.7/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.6/relu_2/Relu_output_0, %onnx::Conv_1548, %onnx::Conv_1549)
#   %/layer2/layer2.7/relu/Relu_output_0 = Relu(%/layer2/layer2.7/conv1/Conv_output_0)
#   %/layer2/layer2.7/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer2/layer2.7/relu/Relu_output_0, %onnx::Conv_1551, %onnx::Conv_1552)
#   %/layer2/layer2.7/relu_1/Relu_output_0 = Relu(%/layer2/layer2.7/conv2/Conv_output_0)
#   %/layer2/layer2.7/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.7/relu_1/Relu_output_0, %onnx::Conv_1554, %onnx::Conv_1555)
#   %/layer2/layer2.7/Add_output_0 = Add(%/layer2/layer2.7/conv3/Conv_output_0, %/layer2/layer2.6/relu_2/Relu_output_0)
#   %/layer2/layer2.7/relu_2/Relu_output_0 = Relu(%/layer2/layer2.7/Add_output_0)
#   %/layer3/layer3.0/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer2/layer2.7/relu_2/Relu_output_0, %onnx::Conv_1557, %onnx::Conv_1558)
#   %/layer3/layer3.0/relu/Relu_output_0 = Relu(%/layer3/layer3.0/conv1/Conv_output_0)
#   %/layer3/layer3.0/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/layer3/layer3.0/relu/Relu_output_0, %onnx::Conv_1560, %onnx::Conv_1561)
#   %/layer3/layer3.0/relu_1/Relu_output_0 = Relu(%/layer3/layer3.0/conv2/Conv_output_0)
#   %/layer3/layer3.0/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.0/relu_1/Relu_output_0, %onnx::Conv_1563, %onnx::Conv_1564)
#   %/layer3/layer3.0/downsample/downsample.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%/layer2/layer2.7/relu_2/Relu_output_0, %onnx::Conv_1566, %onnx::Conv_1567)
#   %/layer3/layer3.0/Add_output_0 = Add(%/layer3/layer3.0/conv3/Conv_output_0, %/layer3/layer3.0/downsample/downsample.0/Conv_output_0)
#   %/layer3/layer3.0/relu_2/Relu_output_0 = Relu(%/layer3/layer3.0/Add_output_0)
#   %/layer3/layer3.1/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.0/relu_2/Relu_output_0, %onnx::Conv_1569, %onnx::Conv_1570)
#   %/layer3/layer3.1/relu/Relu_output_0 = Relu(%/layer3/layer3.1/conv1/Conv_output_0)
#   %/layer3/layer3.1/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.1/relu/Relu_output_0, %onnx::Conv_1572, %onnx::Conv_1573)
#   %/layer3/layer3.1/relu_1/Relu_output_0 = Relu(%/layer3/layer3.1/conv2/Conv_output_0)
#   %/layer3/layer3.1/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.1/relu_1/Relu_output_0, %onnx::Conv_1575, %onnx::Conv_1576)
#   %/layer3/layer3.1/Add_output_0 = Add(%/layer3/layer3.1/conv3/Conv_output_0, %/layer3/layer3.0/relu_2/Relu_output_0)
#   %/layer3/layer3.1/relu_2/Relu_output_0 = Relu(%/layer3/layer3.1/Add_output_0)
#   %/layer3/layer3.2/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.1/relu_2/Relu_output_0, %onnx::Conv_1578, %onnx::Conv_1579)
#   %/layer3/layer3.2/relu/Relu_output_0 = Relu(%/layer3/layer3.2/conv1/Conv_output_0)
#   %/layer3/layer3.2/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.2/relu/Relu_output_0, %onnx::Conv_1581, %onnx::Conv_1582)
#   %/layer3/layer3.2/relu_1/Relu_output_0 = Relu(%/layer3/layer3.2/conv2/Conv_output_0)
#   %/layer3/layer3.2/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.2/relu_1/Relu_output_0, %onnx::Conv_1584, %onnx::Conv_1585)
#   %/layer3/layer3.2/Add_output_0 = Add(%/layer3/layer3.2/conv3/Conv_output_0, %/layer3/layer3.1/relu_2/Relu_output_0)
#   %/layer3/layer3.2/relu_2/Relu_output_0 = Relu(%/layer3/layer3.2/Add_output_0)
#   %/layer3/layer3.3/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.2/relu_2/Relu_output_0, %onnx::Conv_1587, %onnx::Conv_1588)
#   %/layer3/layer3.3/relu/Relu_output_0 = Relu(%/layer3/layer3.3/conv1/Conv_output_0)
#   %/layer3/layer3.3/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.3/relu/Relu_output_0, %onnx::Conv_1590, %onnx::Conv_1591)
#   %/layer3/layer3.3/relu_1/Relu_output_0 = Relu(%/layer3/layer3.3/conv2/Conv_output_0)
#   %/layer3/layer3.3/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.3/relu_1/Relu_output_0, %onnx::Conv_1593, %onnx::Conv_1594)
#   %/layer3/layer3.3/Add_output_0 = Add(%/layer3/layer3.3/conv3/Conv_output_0, %/layer3/layer3.2/relu_2/Relu_output_0)
#   %/layer3/layer3.3/relu_2/Relu_output_0 = Relu(%/layer3/layer3.3/Add_output_0)
#   %/layer3/layer3.4/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.3/relu_2/Relu_output_0, %onnx::Conv_1596, %onnx::Conv_1597)
#   %/layer3/layer3.4/relu/Relu_output_0 = Relu(%/layer3/layer3.4/conv1/Conv_output_0)
#   %/layer3/layer3.4/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.4/relu/Relu_output_0, %onnx::Conv_1599, %onnx::Conv_1600)
#   %/layer3/layer3.4/relu_1/Relu_output_0 = Relu(%/layer3/layer3.4/conv2/Conv_output_0)
#   %/layer3/layer3.4/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.4/relu_1/Relu_output_0, %onnx::Conv_1602, %onnx::Conv_1603)
#   %/layer3/layer3.4/Add_output_0 = Add(%/layer3/layer3.4/conv3/Conv_output_0, %/layer3/layer3.3/relu_2/Relu_output_0)
#   %/layer3/layer3.4/relu_2/Relu_output_0 = Relu(%/layer3/layer3.4/Add_output_0)
#   %/layer3/layer3.5/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.4/relu_2/Relu_output_0, %onnx::Conv_1605, %onnx::Conv_1606)
#   %/layer3/layer3.5/relu/Relu_output_0 = Relu(%/layer3/layer3.5/conv1/Conv_output_0)
#   %/layer3/layer3.5/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.5/relu/Relu_output_0, %onnx::Conv_1608, %onnx::Conv_1609)
#   %/layer3/layer3.5/relu_1/Relu_output_0 = Relu(%/layer3/layer3.5/conv2/Conv_output_0)
#   %/layer3/layer3.5/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.5/relu_1/Relu_output_0, %onnx::Conv_1611, %onnx::Conv_1612)
#   %/layer3/layer3.5/Add_output_0 = Add(%/layer3/layer3.5/conv3/Conv_output_0, %/layer3/layer3.4/relu_2/Relu_output_0)
#   %/layer3/layer3.5/relu_2/Relu_output_0 = Relu(%/layer3/layer3.5/Add_output_0)
#   %/layer3/layer3.6/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.5/relu_2/Relu_output_0, %onnx::Conv_1614, %onnx::Conv_1615)
#   %/layer3/layer3.6/relu/Relu_output_0 = Relu(%/layer3/layer3.6/conv1/Conv_output_0)
#   %/layer3/layer3.6/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.6/relu/Relu_output_0, %onnx::Conv_1617, %onnx::Conv_1618)
#   %/layer3/layer3.6/relu_1/Relu_output_0 = Relu(%/layer3/layer3.6/conv2/Conv_output_0)
#   %/layer3/layer3.6/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.6/relu_1/Relu_output_0, %onnx::Conv_1620, %onnx::Conv_1621)
#   %/layer3/layer3.6/Add_output_0 = Add(%/layer3/layer3.6/conv3/Conv_output_0, %/layer3/layer3.5/relu_2/Relu_output_0)
#   %/layer3/layer3.6/relu_2/Relu_output_0 = Relu(%/layer3/layer3.6/Add_output_0)
#   %/layer3/layer3.7/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.6/relu_2/Relu_output_0, %onnx::Conv_1623, %onnx::Conv_1624)
#   %/layer3/layer3.7/relu/Relu_output_0 = Relu(%/layer3/layer3.7/conv1/Conv_output_0)
#   %/layer3/layer3.7/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.7/relu/Relu_output_0, %onnx::Conv_1626, %onnx::Conv_1627)
#   %/layer3/layer3.7/relu_1/Relu_output_0 = Relu(%/layer3/layer3.7/conv2/Conv_output_0)
#   %/layer3/layer3.7/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.7/relu_1/Relu_output_0, %onnx::Conv_1629, %onnx::Conv_1630)
#   %/layer3/layer3.7/Add_output_0 = Add(%/layer3/layer3.7/conv3/Conv_output_0, %/layer3/layer3.6/relu_2/Relu_output_0)
#   %/layer3/layer3.7/relu_2/Relu_output_0 = Relu(%/layer3/layer3.7/Add_output_0)
#   %/layer3/layer3.8/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.7/relu_2/Relu_output_0, %onnx::Conv_1632, %onnx::Conv_1633)
#   %/layer3/layer3.8/relu/Relu_output_0 = Relu(%/layer3/layer3.8/conv1/Conv_output_0)
#   %/layer3/layer3.8/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.8/relu/Relu_output_0, %onnx::Conv_1635, %onnx::Conv_1636)
#   %/layer3/layer3.8/relu_1/Relu_output_0 = Relu(%/layer3/layer3.8/conv2/Conv_output_0)
#   %/layer3/layer3.8/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.8/relu_1/Relu_output_0, %onnx::Conv_1638, %onnx::Conv_1639)
#   %/layer3/layer3.8/Add_output_0 = Add(%/layer3/layer3.8/conv3/Conv_output_0, %/layer3/layer3.7/relu_2/Relu_output_0)
#   %/layer3/layer3.8/relu_2/Relu_output_0 = Relu(%/layer3/layer3.8/Add_output_0)
#   %/layer3/layer3.9/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.8/relu_2/Relu_output_0, %onnx::Conv_1641, %onnx::Conv_1642)
#   %/layer3/layer3.9/relu/Relu_output_0 = Relu(%/layer3/layer3.9/conv1/Conv_output_0)
#   %/layer3/layer3.9/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.9/relu/Relu_output_0, %onnx::Conv_1644, %onnx::Conv_1645)
#   %/layer3/layer3.9/relu_1/Relu_output_0 = Relu(%/layer3/layer3.9/conv2/Conv_output_0)
#   %/layer3/layer3.9/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.9/relu_1/Relu_output_0, %onnx::Conv_1647, %onnx::Conv_1648)
#   %/layer3/layer3.9/Add_output_0 = Add(%/layer3/layer3.9/conv3/Conv_output_0, %/layer3/layer3.8/relu_2/Relu_output_0)
#   %/layer3/layer3.9/relu_2/Relu_output_0 = Relu(%/layer3/layer3.9/Add_output_0)
#   %/layer3/layer3.10/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.9/relu_2/Relu_output_0, %onnx::Conv_1650, %onnx::Conv_1651)
#   %/layer3/layer3.10/relu/Relu_output_0 = Relu(%/layer3/layer3.10/conv1/Conv_output_0)
#   %/layer3/layer3.10/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.10/relu/Relu_output_0, %onnx::Conv_1653, %onnx::Conv_1654)
#   %/layer3/layer3.10/relu_1/Relu_output_0 = Relu(%/layer3/layer3.10/conv2/Conv_output_0)
#   %/layer3/layer3.10/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.10/relu_1/Relu_output_0, %onnx::Conv_1656, %onnx::Conv_1657)
#   %/layer3/layer3.10/Add_output_0 = Add(%/layer3/layer3.10/conv3/Conv_output_0, %/layer3/layer3.9/relu_2/Relu_output_0)
#   %/layer3/layer3.10/relu_2/Relu_output_0 = Relu(%/layer3/layer3.10/Add_output_0)
#   %/layer3/layer3.11/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.10/relu_2/Relu_output_0, %onnx::Conv_1659, %onnx::Conv_1660)
#   %/layer3/layer3.11/relu/Relu_output_0 = Relu(%/layer3/layer3.11/conv1/Conv_output_0)
#   %/layer3/layer3.11/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.11/relu/Relu_output_0, %onnx::Conv_1662, %onnx::Conv_1663)
#   %/layer3/layer3.11/relu_1/Relu_output_0 = Relu(%/layer3/layer3.11/conv2/Conv_output_0)
#   %/layer3/layer3.11/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.11/relu_1/Relu_output_0, %onnx::Conv_1665, %onnx::Conv_1666)
#   %/layer3/layer3.11/Add_output_0 = Add(%/layer3/layer3.11/conv3/Conv_output_0, %/layer3/layer3.10/relu_2/Relu_output_0)
#   %/layer3/layer3.11/relu_2/Relu_output_0 = Relu(%/layer3/layer3.11/Add_output_0)
#   %/layer3/layer3.12/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.11/relu_2/Relu_output_0, %onnx::Conv_1668, %onnx::Conv_1669)
#   %/layer3/layer3.12/relu/Relu_output_0 = Relu(%/layer3/layer3.12/conv1/Conv_output_0)
#   %/layer3/layer3.12/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.12/relu/Relu_output_0, %onnx::Conv_1671, %onnx::Conv_1672)
#   %/layer3/layer3.12/relu_1/Relu_output_0 = Relu(%/layer3/layer3.12/conv2/Conv_output_0)
#   %/layer3/layer3.12/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.12/relu_1/Relu_output_0, %onnx::Conv_1674, %onnx::Conv_1675)
#   %/layer3/layer3.12/Add_output_0 = Add(%/layer3/layer3.12/conv3/Conv_output_0, %/layer3/layer3.11/relu_2/Relu_output_0)
#   %/layer3/layer3.12/relu_2/Relu_output_0 = Relu(%/layer3/layer3.12/Add_output_0)
#   %/layer3/layer3.13/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.12/relu_2/Relu_output_0, %onnx::Conv_1677, %onnx::Conv_1678)
#   %/layer3/layer3.13/relu/Relu_output_0 = Relu(%/layer3/layer3.13/conv1/Conv_output_0)
#   %/layer3/layer3.13/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.13/relu/Relu_output_0, %onnx::Conv_1680, %onnx::Conv_1681)
#   %/layer3/layer3.13/relu_1/Relu_output_0 = Relu(%/layer3/layer3.13/conv2/Conv_output_0)
#   %/layer3/layer3.13/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.13/relu_1/Relu_output_0, %onnx::Conv_1683, %onnx::Conv_1684)
#   %/layer3/layer3.13/Add_output_0 = Add(%/layer3/layer3.13/conv3/Conv_output_0, %/layer3/layer3.12/relu_2/Relu_output_0)
#   %/layer3/layer3.13/relu_2/Relu_output_0 = Relu(%/layer3/layer3.13/Add_output_0)
#   %/layer3/layer3.14/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.13/relu_2/Relu_output_0, %onnx::Conv_1686, %onnx::Conv_1687)
#   %/layer3/layer3.14/relu/Relu_output_0 = Relu(%/layer3/layer3.14/conv1/Conv_output_0)
#   %/layer3/layer3.14/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.14/relu/Relu_output_0, %onnx::Conv_1689, %onnx::Conv_1690)
#   %/layer3/layer3.14/relu_1/Relu_output_0 = Relu(%/layer3/layer3.14/conv2/Conv_output_0)
#   %/layer3/layer3.14/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.14/relu_1/Relu_output_0, %onnx::Conv_1692, %onnx::Conv_1693)
#   %/layer3/layer3.14/Add_output_0 = Add(%/layer3/layer3.14/conv3/Conv_output_0, %/layer3/layer3.13/relu_2/Relu_output_0)
#   %/layer3/layer3.14/relu_2/Relu_output_0 = Relu(%/layer3/layer3.14/Add_output_0)
#   %/layer3/layer3.15/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.14/relu_2/Relu_output_0, %onnx::Conv_1695, %onnx::Conv_1696)
#   %/layer3/layer3.15/relu/Relu_output_0 = Relu(%/layer3/layer3.15/conv1/Conv_output_0)
#   %/layer3/layer3.15/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.15/relu/Relu_output_0, %onnx::Conv_1698, %onnx::Conv_1699)
#   %/layer3/layer3.15/relu_1/Relu_output_0 = Relu(%/layer3/layer3.15/conv2/Conv_output_0)
#   %/layer3/layer3.15/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.15/relu_1/Relu_output_0, %onnx::Conv_1701, %onnx::Conv_1702)
#   %/layer3/layer3.15/Add_output_0 = Add(%/layer3/layer3.15/conv3/Conv_output_0, %/layer3/layer3.14/relu_2/Relu_output_0)
#   %/layer3/layer3.15/relu_2/Relu_output_0 = Relu(%/layer3/layer3.15/Add_output_0)
#   %/layer3/layer3.16/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.15/relu_2/Relu_output_0, %onnx::Conv_1704, %onnx::Conv_1705)
#   %/layer3/layer3.16/relu/Relu_output_0 = Relu(%/layer3/layer3.16/conv1/Conv_output_0)
#   %/layer3/layer3.16/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.16/relu/Relu_output_0, %onnx::Conv_1707, %onnx::Conv_1708)
#   %/layer3/layer3.16/relu_1/Relu_output_0 = Relu(%/layer3/layer3.16/conv2/Conv_output_0)
#   %/layer3/layer3.16/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.16/relu_1/Relu_output_0, %onnx::Conv_1710, %onnx::Conv_1711)
#   %/layer3/layer3.16/Add_output_0 = Add(%/layer3/layer3.16/conv3/Conv_output_0, %/layer3/layer3.15/relu_2/Relu_output_0)
#   %/layer3/layer3.16/relu_2/Relu_output_0 = Relu(%/layer3/layer3.16/Add_output_0)
#   %/layer3/layer3.17/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.16/relu_2/Relu_output_0, %onnx::Conv_1713, %onnx::Conv_1714)
#   %/layer3/layer3.17/relu/Relu_output_0 = Relu(%/layer3/layer3.17/conv1/Conv_output_0)
#   %/layer3/layer3.17/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.17/relu/Relu_output_0, %onnx::Conv_1716, %onnx::Conv_1717)
#   %/layer3/layer3.17/relu_1/Relu_output_0 = Relu(%/layer3/layer3.17/conv2/Conv_output_0)
#   %/layer3/layer3.17/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.17/relu_1/Relu_output_0, %onnx::Conv_1719, %onnx::Conv_1720)
#   %/layer3/layer3.17/Add_output_0 = Add(%/layer3/layer3.17/conv3/Conv_output_0, %/layer3/layer3.16/relu_2/Relu_output_0)
#   %/layer3/layer3.17/relu_2/Relu_output_0 = Relu(%/layer3/layer3.17/Add_output_0)
#   %/layer3/layer3.18/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.17/relu_2/Relu_output_0, %onnx::Conv_1722, %onnx::Conv_1723)
#   %/layer3/layer3.18/relu/Relu_output_0 = Relu(%/layer3/layer3.18/conv1/Conv_output_0)
#   %/layer3/layer3.18/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.18/relu/Relu_output_0, %onnx::Conv_1725, %onnx::Conv_1726)
#   %/layer3/layer3.18/relu_1/Relu_output_0 = Relu(%/layer3/layer3.18/conv2/Conv_output_0)
#   %/layer3/layer3.18/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.18/relu_1/Relu_output_0, %onnx::Conv_1728, %onnx::Conv_1729)
#   %/layer3/layer3.18/Add_output_0 = Add(%/layer3/layer3.18/conv3/Conv_output_0, %/layer3/layer3.17/relu_2/Relu_output_0)
#   %/layer3/layer3.18/relu_2/Relu_output_0 = Relu(%/layer3/layer3.18/Add_output_0)
#   %/layer3/layer3.19/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.18/relu_2/Relu_output_0, %onnx::Conv_1731, %onnx::Conv_1732)
#   %/layer3/layer3.19/relu/Relu_output_0 = Relu(%/layer3/layer3.19/conv1/Conv_output_0)
#   %/layer3/layer3.19/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.19/relu/Relu_output_0, %onnx::Conv_1734, %onnx::Conv_1735)
#   %/layer3/layer3.19/relu_1/Relu_output_0 = Relu(%/layer3/layer3.19/conv2/Conv_output_0)
#   %/layer3/layer3.19/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.19/relu_1/Relu_output_0, %onnx::Conv_1737, %onnx::Conv_1738)
#   %/layer3/layer3.19/Add_output_0 = Add(%/layer3/layer3.19/conv3/Conv_output_0, %/layer3/layer3.18/relu_2/Relu_output_0)
#   %/layer3/layer3.19/relu_2/Relu_output_0 = Relu(%/layer3/layer3.19/Add_output_0)
#   %/layer3/layer3.20/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.19/relu_2/Relu_output_0, %onnx::Conv_1740, %onnx::Conv_1741)
#   %/layer3/layer3.20/relu/Relu_output_0 = Relu(%/layer3/layer3.20/conv1/Conv_output_0)
#   %/layer3/layer3.20/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.20/relu/Relu_output_0, %onnx::Conv_1743, %onnx::Conv_1744)
#   %/layer3/layer3.20/relu_1/Relu_output_0 = Relu(%/layer3/layer3.20/conv2/Conv_output_0)
#   %/layer3/layer3.20/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.20/relu_1/Relu_output_0, %onnx::Conv_1746, %onnx::Conv_1747)
#   %/layer3/layer3.20/Add_output_0 = Add(%/layer3/layer3.20/conv3/Conv_output_0, %/layer3/layer3.19/relu_2/Relu_output_0)
#   %/layer3/layer3.20/relu_2/Relu_output_0 = Relu(%/layer3/layer3.20/Add_output_0)
#   %/layer3/layer3.21/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.20/relu_2/Relu_output_0, %onnx::Conv_1749, %onnx::Conv_1750)
#   %/layer3/layer3.21/relu/Relu_output_0 = Relu(%/layer3/layer3.21/conv1/Conv_output_0)
#   %/layer3/layer3.21/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.21/relu/Relu_output_0, %onnx::Conv_1752, %onnx::Conv_1753)
#   %/layer3/layer3.21/relu_1/Relu_output_0 = Relu(%/layer3/layer3.21/conv2/Conv_output_0)
#   %/layer3/layer3.21/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.21/relu_1/Relu_output_0, %onnx::Conv_1755, %onnx::Conv_1756)
#   %/layer3/layer3.21/Add_output_0 = Add(%/layer3/layer3.21/conv3/Conv_output_0, %/layer3/layer3.20/relu_2/Relu_output_0)
#   %/layer3/layer3.21/relu_2/Relu_output_0 = Relu(%/layer3/layer3.21/Add_output_0)
#   %/layer3/layer3.22/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.21/relu_2/Relu_output_0, %onnx::Conv_1758, %onnx::Conv_1759)
#   %/layer3/layer3.22/relu/Relu_output_0 = Relu(%/layer3/layer3.22/conv1/Conv_output_0)
#   %/layer3/layer3.22/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.22/relu/Relu_output_0, %onnx::Conv_1761, %onnx::Conv_1762)
#   %/layer3/layer3.22/relu_1/Relu_output_0 = Relu(%/layer3/layer3.22/conv2/Conv_output_0)
#   %/layer3/layer3.22/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.22/relu_1/Relu_output_0, %onnx::Conv_1764, %onnx::Conv_1765)
#   %/layer3/layer3.22/Add_output_0 = Add(%/layer3/layer3.22/conv3/Conv_output_0, %/layer3/layer3.21/relu_2/Relu_output_0)
#   %/layer3/layer3.22/relu_2/Relu_output_0 = Relu(%/layer3/layer3.22/Add_output_0)
#   %/layer3/layer3.23/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.22/relu_2/Relu_output_0, %onnx::Conv_1767, %onnx::Conv_1768)
#   %/layer3/layer3.23/relu/Relu_output_0 = Relu(%/layer3/layer3.23/conv1/Conv_output_0)
#   %/layer3/layer3.23/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.23/relu/Relu_output_0, %onnx::Conv_1770, %onnx::Conv_1771)
#   %/layer3/layer3.23/relu_1/Relu_output_0 = Relu(%/layer3/layer3.23/conv2/Conv_output_0)
#   %/layer3/layer3.23/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.23/relu_1/Relu_output_0, %onnx::Conv_1773, %onnx::Conv_1774)
#   %/layer3/layer3.23/Add_output_0 = Add(%/layer3/layer3.23/conv3/Conv_output_0, %/layer3/layer3.22/relu_2/Relu_output_0)
#   %/layer3/layer3.23/relu_2/Relu_output_0 = Relu(%/layer3/layer3.23/Add_output_0)
#   %/layer3/layer3.24/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.23/relu_2/Relu_output_0, %onnx::Conv_1776, %onnx::Conv_1777)
#   %/layer3/layer3.24/relu/Relu_output_0 = Relu(%/layer3/layer3.24/conv1/Conv_output_0)
#   %/layer3/layer3.24/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.24/relu/Relu_output_0, %onnx::Conv_1779, %onnx::Conv_1780)
#   %/layer3/layer3.24/relu_1/Relu_output_0 = Relu(%/layer3/layer3.24/conv2/Conv_output_0)
#   %/layer3/layer3.24/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.24/relu_1/Relu_output_0, %onnx::Conv_1782, %onnx::Conv_1783)
#   %/layer3/layer3.24/Add_output_0 = Add(%/layer3/layer3.24/conv3/Conv_output_0, %/layer3/layer3.23/relu_2/Relu_output_0)
#   %/layer3/layer3.24/relu_2/Relu_output_0 = Relu(%/layer3/layer3.24/Add_output_0)
#   %/layer3/layer3.25/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.24/relu_2/Relu_output_0, %onnx::Conv_1785, %onnx::Conv_1786)
#   %/layer3/layer3.25/relu/Relu_output_0 = Relu(%/layer3/layer3.25/conv1/Conv_output_0)
#   %/layer3/layer3.25/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.25/relu/Relu_output_0, %onnx::Conv_1788, %onnx::Conv_1789)
#   %/layer3/layer3.25/relu_1/Relu_output_0 = Relu(%/layer3/layer3.25/conv2/Conv_output_0)
#   %/layer3/layer3.25/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.25/relu_1/Relu_output_0, %onnx::Conv_1791, %onnx::Conv_1792)
#   %/layer3/layer3.25/Add_output_0 = Add(%/layer3/layer3.25/conv3/Conv_output_0, %/layer3/layer3.24/relu_2/Relu_output_0)
#   %/layer3/layer3.25/relu_2/Relu_output_0 = Relu(%/layer3/layer3.25/Add_output_0)
#   %/layer3/layer3.26/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.25/relu_2/Relu_output_0, %onnx::Conv_1794, %onnx::Conv_1795)
#   %/layer3/layer3.26/relu/Relu_output_0 = Relu(%/layer3/layer3.26/conv1/Conv_output_0)
#   %/layer3/layer3.26/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.26/relu/Relu_output_0, %onnx::Conv_1797, %onnx::Conv_1798)
#   %/layer3/layer3.26/relu_1/Relu_output_0 = Relu(%/layer3/layer3.26/conv2/Conv_output_0)
#   %/layer3/layer3.26/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.26/relu_1/Relu_output_0, %onnx::Conv_1800, %onnx::Conv_1801)
#   %/layer3/layer3.26/Add_output_0 = Add(%/layer3/layer3.26/conv3/Conv_output_0, %/layer3/layer3.25/relu_2/Relu_output_0)
#   %/layer3/layer3.26/relu_2/Relu_output_0 = Relu(%/layer3/layer3.26/Add_output_0)
#   %/layer3/layer3.27/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.26/relu_2/Relu_output_0, %onnx::Conv_1803, %onnx::Conv_1804)
#   %/layer3/layer3.27/relu/Relu_output_0 = Relu(%/layer3/layer3.27/conv1/Conv_output_0)
#   %/layer3/layer3.27/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.27/relu/Relu_output_0, %onnx::Conv_1806, %onnx::Conv_1807)
#   %/layer3/layer3.27/relu_1/Relu_output_0 = Relu(%/layer3/layer3.27/conv2/Conv_output_0)
#   %/layer3/layer3.27/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.27/relu_1/Relu_output_0, %onnx::Conv_1809, %onnx::Conv_1810)
#   %/layer3/layer3.27/Add_output_0 = Add(%/layer3/layer3.27/conv3/Conv_output_0, %/layer3/layer3.26/relu_2/Relu_output_0)
#   %/layer3/layer3.27/relu_2/Relu_output_0 = Relu(%/layer3/layer3.27/Add_output_0)
#   %/layer3/layer3.28/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.27/relu_2/Relu_output_0, %onnx::Conv_1812, %onnx::Conv_1813)
#   %/layer3/layer3.28/relu/Relu_output_0 = Relu(%/layer3/layer3.28/conv1/Conv_output_0)
#   %/layer3/layer3.28/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.28/relu/Relu_output_0, %onnx::Conv_1815, %onnx::Conv_1816)
#   %/layer3/layer3.28/relu_1/Relu_output_0 = Relu(%/layer3/layer3.28/conv2/Conv_output_0)
#   %/layer3/layer3.28/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.28/relu_1/Relu_output_0, %onnx::Conv_1818, %onnx::Conv_1819)
#   %/layer3/layer3.28/Add_output_0 = Add(%/layer3/layer3.28/conv3/Conv_output_0, %/layer3/layer3.27/relu_2/Relu_output_0)
#   %/layer3/layer3.28/relu_2/Relu_output_0 = Relu(%/layer3/layer3.28/Add_output_0)
#   %/layer3/layer3.29/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.28/relu_2/Relu_output_0, %onnx::Conv_1821, %onnx::Conv_1822)
#   %/layer3/layer3.29/relu/Relu_output_0 = Relu(%/layer3/layer3.29/conv1/Conv_output_0)
#   %/layer3/layer3.29/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.29/relu/Relu_output_0, %onnx::Conv_1824, %onnx::Conv_1825)
#   %/layer3/layer3.29/relu_1/Relu_output_0 = Relu(%/layer3/layer3.29/conv2/Conv_output_0)
#   %/layer3/layer3.29/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.29/relu_1/Relu_output_0, %onnx::Conv_1827, %onnx::Conv_1828)
#   %/layer3/layer3.29/Add_output_0 = Add(%/layer3/layer3.29/conv3/Conv_output_0, %/layer3/layer3.28/relu_2/Relu_output_0)
#   %/layer3/layer3.29/relu_2/Relu_output_0 = Relu(%/layer3/layer3.29/Add_output_0)
#   %/layer3/layer3.30/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.29/relu_2/Relu_output_0, %onnx::Conv_1830, %onnx::Conv_1831)
#   %/layer3/layer3.30/relu/Relu_output_0 = Relu(%/layer3/layer3.30/conv1/Conv_output_0)
#   %/layer3/layer3.30/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.30/relu/Relu_output_0, %onnx::Conv_1833, %onnx::Conv_1834)
#   %/layer3/layer3.30/relu_1/Relu_output_0 = Relu(%/layer3/layer3.30/conv2/Conv_output_0)
#   %/layer3/layer3.30/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.30/relu_1/Relu_output_0, %onnx::Conv_1836, %onnx::Conv_1837)
#   %/layer3/layer3.30/Add_output_0 = Add(%/layer3/layer3.30/conv3/Conv_output_0, %/layer3/layer3.29/relu_2/Relu_output_0)
#   %/layer3/layer3.30/relu_2/Relu_output_0 = Relu(%/layer3/layer3.30/Add_output_0)
#   %/layer3/layer3.31/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.30/relu_2/Relu_output_0, %onnx::Conv_1839, %onnx::Conv_1840)
#   %/layer3/layer3.31/relu/Relu_output_0 = Relu(%/layer3/layer3.31/conv1/Conv_output_0)
#   %/layer3/layer3.31/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.31/relu/Relu_output_0, %onnx::Conv_1842, %onnx::Conv_1843)
#   %/layer3/layer3.31/relu_1/Relu_output_0 = Relu(%/layer3/layer3.31/conv2/Conv_output_0)
#   %/layer3/layer3.31/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.31/relu_1/Relu_output_0, %onnx::Conv_1845, %onnx::Conv_1846)
#   %/layer3/layer3.31/Add_output_0 = Add(%/layer3/layer3.31/conv3/Conv_output_0, %/layer3/layer3.30/relu_2/Relu_output_0)
#   %/layer3/layer3.31/relu_2/Relu_output_0 = Relu(%/layer3/layer3.31/Add_output_0)
#   %/layer3/layer3.32/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.31/relu_2/Relu_output_0, %onnx::Conv_1848, %onnx::Conv_1849)
#   %/layer3/layer3.32/relu/Relu_output_0 = Relu(%/layer3/layer3.32/conv1/Conv_output_0)
#   %/layer3/layer3.32/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.32/relu/Relu_output_0, %onnx::Conv_1851, %onnx::Conv_1852)
#   %/layer3/layer3.32/relu_1/Relu_output_0 = Relu(%/layer3/layer3.32/conv2/Conv_output_0)
#   %/layer3/layer3.32/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.32/relu_1/Relu_output_0, %onnx::Conv_1854, %onnx::Conv_1855)
#   %/layer3/layer3.32/Add_output_0 = Add(%/layer3/layer3.32/conv3/Conv_output_0, %/layer3/layer3.31/relu_2/Relu_output_0)
#   %/layer3/layer3.32/relu_2/Relu_output_0 = Relu(%/layer3/layer3.32/Add_output_0)
#   %/layer3/layer3.33/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.32/relu_2/Relu_output_0, %onnx::Conv_1857, %onnx::Conv_1858)
#   %/layer3/layer3.33/relu/Relu_output_0 = Relu(%/layer3/layer3.33/conv1/Conv_output_0)
#   %/layer3/layer3.33/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.33/relu/Relu_output_0, %onnx::Conv_1860, %onnx::Conv_1861)
#   %/layer3/layer3.33/relu_1/Relu_output_0 = Relu(%/layer3/layer3.33/conv2/Conv_output_0)
#   %/layer3/layer3.33/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.33/relu_1/Relu_output_0, %onnx::Conv_1863, %onnx::Conv_1864)
#   %/layer3/layer3.33/Add_output_0 = Add(%/layer3/layer3.33/conv3/Conv_output_0, %/layer3/layer3.32/relu_2/Relu_output_0)
#   %/layer3/layer3.33/relu_2/Relu_output_0 = Relu(%/layer3/layer3.33/Add_output_0)
#   %/layer3/layer3.34/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.33/relu_2/Relu_output_0, %onnx::Conv_1866, %onnx::Conv_1867)
#   %/layer3/layer3.34/relu/Relu_output_0 = Relu(%/layer3/layer3.34/conv1/Conv_output_0)
#   %/layer3/layer3.34/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.34/relu/Relu_output_0, %onnx::Conv_1869, %onnx::Conv_1870)
#   %/layer3/layer3.34/relu_1/Relu_output_0 = Relu(%/layer3/layer3.34/conv2/Conv_output_0)
#   %/layer3/layer3.34/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.34/relu_1/Relu_output_0, %onnx::Conv_1872, %onnx::Conv_1873)
#   %/layer3/layer3.34/Add_output_0 = Add(%/layer3/layer3.34/conv3/Conv_output_0, %/layer3/layer3.33/relu_2/Relu_output_0)
#   %/layer3/layer3.34/relu_2/Relu_output_0 = Relu(%/layer3/layer3.34/Add_output_0)
#   %/layer3/layer3.35/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.34/relu_2/Relu_output_0, %onnx::Conv_1875, %onnx::Conv_1876)
#   %/layer3/layer3.35/relu/Relu_output_0 = Relu(%/layer3/layer3.35/conv1/Conv_output_0)
#   %/layer3/layer3.35/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer3/layer3.35/relu/Relu_output_0, %onnx::Conv_1878, %onnx::Conv_1879)
#   %/layer3/layer3.35/relu_1/Relu_output_0 = Relu(%/layer3/layer3.35/conv2/Conv_output_0)
#   %/layer3/layer3.35/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.35/relu_1/Relu_output_0, %onnx::Conv_1881, %onnx::Conv_1882)
#   %/layer3/layer3.35/Add_output_0 = Add(%/layer3/layer3.35/conv3/Conv_output_0, %/layer3/layer3.34/relu_2/Relu_output_0)
#   %/layer3/layer3.35/relu_2/Relu_output_0 = Relu(%/layer3/layer3.35/Add_output_0)
#   %/layer4/layer4.0/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer3/layer3.35/relu_2/Relu_output_0, %onnx::Conv_1884, %onnx::Conv_1885)
#   %/layer4/layer4.0/relu/Relu_output_0 = Relu(%/layer4/layer4.0/conv1/Conv_output_0)
#   %/layer4/layer4.0/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/layer4/layer4.0/relu/Relu_output_0, %onnx::Conv_1887, %onnx::Conv_1888)
#   %/layer4/layer4.0/relu_1/Relu_output_0 = Relu(%/layer4/layer4.0/conv2/Conv_output_0)
#   %/layer4/layer4.0/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer4/layer4.0/relu_1/Relu_output_0, %onnx::Conv_1890, %onnx::Conv_1891)
#   %/layer4/layer4.0/downsample/downsample.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%/layer3/layer3.35/relu_2/Relu_output_0, %onnx::Conv_1893, %onnx::Conv_1894)
#   %/layer4/layer4.0/Add_output_0 = Add(%/layer4/layer4.0/conv3/Conv_output_0, %/layer4/layer4.0/downsample/downsample.0/Conv_output_0)
#   %/layer4/layer4.0/relu_2/Relu_output_0 = Relu(%/layer4/layer4.0/Add_output_0)
#   %/layer4/layer4.1/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer4/layer4.0/relu_2/Relu_output_0, %onnx::Conv_1896, %onnx::Conv_1897)
#   %/layer4/layer4.1/relu/Relu_output_0 = Relu(%/layer4/layer4.1/conv1/Conv_output_0)
#   %/layer4/layer4.1/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer4/layer4.1/relu/Relu_output_0, %onnx::Conv_1899, %onnx::Conv_1900)
#   %/layer4/layer4.1/relu_1/Relu_output_0 = Relu(%/layer4/layer4.1/conv2/Conv_output_0)
#   %/layer4/layer4.1/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer4/layer4.1/relu_1/Relu_output_0, %onnx::Conv_1902, %onnx::Conv_1903)
#   %/layer4/layer4.1/Add_output_0 = Add(%/layer4/layer4.1/conv3/Conv_output_0, %/layer4/layer4.0/relu_2/Relu_output_0)
#   %/layer4/layer4.1/relu_2/Relu_output_0 = Relu(%/layer4/layer4.1/Add_output_0)
#   %/layer4/layer4.2/conv1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer4/layer4.1/relu_2/Relu_output_0, %onnx::Conv_1905, %onnx::Conv_1906)
#   %/layer4/layer4.2/relu/Relu_output_0 = Relu(%/layer4/layer4.2/conv1/Conv_output_0)
#   %/layer4/layer4.2/conv2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/layer4/layer4.2/relu/Relu_output_0, %onnx::Conv_1908, %onnx::Conv_1909)
#   %/layer4/layer4.2/relu_1/Relu_output_0 = Relu(%/layer4/layer4.2/conv2/Conv_output_0)
#   %/layer4/layer4.2/conv3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/layer4/layer4.2/relu_1/Relu_output_0, %onnx::Conv_1911, %onnx::Conv_1912)
#   %/layer4/layer4.2/Add_output_0 = Add(%/layer4/layer4.2/conv3/Conv_output_0, %/layer4/layer4.1/relu_2/Relu_output_0)
#   %/layer4/layer4.2/relu_2/Relu_output_0 = Relu(%/layer4/layer4.2/Add_output_0)
#   %/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/layer4/layer4.2/relu_2/Relu_output_0)
#   %/Flatten_output_0 = Flatten[axis = 1](%/avgpool/GlobalAveragePool_output_0)
#   %output = Gemm[alpha = 1, beta = 1, transB = 1](%/Flatten_output_0, %fc.weight, %fc.bias)
#   return %output
# }

# %%
try:
    onnx.checker.check_model(model)
    print("모델 검증 성공")
except onnx.checker.ValidationError as e:
    print("모델 검증 실패")
    print(e)
# Out:
# 모델 검증 성공

# %%
# 모델 시각화
netron.start (ONNX_PATH)
# Out:
# Serving './onnx/resnet152.onnx' at http://localhost:8080
# ('localhost', 8080)
