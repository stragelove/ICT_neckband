# %%
import os
import numpy as np
import Preprocessor as pp
from tqdm import tqdm
import glob

# %%
DATASET = "./Dataset"
OUTPUT = "./calibration"

SAMPLE_RATE = 16000
DURATION = 1
NUM_SAMPLES = int(SAMPLE_RATE * DURATION)
WINDOW_SIZE = 512
HOP_SIZE = 160
MEL_BINS = 64
FMIN = 50
FMAX = 8000

# %%
filepaths = []

for root, _, files in os.walk(DATASET):
    
    for file in files:
        if file.lower().endswith(".wav"):
            filepaths.append(os.path.join(root, file))

print(len(filepaths))
# Out:
# 3000

# %%
logmel = pp.logmel(filepaths[0], NUM_SAMPLES)
logmel = logmel.squeeze(0)
print(logmel.shape)
print(type(logmel))
# Out:
# (1, 64, 101)
# <class 'numpy.ndarray'>

# %%
os.makedirs(OUTPUT, exist_ok=True)
for path in tqdm(filepaths, desc="file convert", leave=True):
    file = path.split("\\")[-1]
    # print(file)
    data = pp.logmel(path, NUM_SAMPLES)
    scale_data = pp.scale(data)
    output = os.path.join(OUTPUT, file.replace(".wav", ".npy"))
    # print(output)
    np.save(output, data)
# Out:
# file convert: 100%|██████████| 3000/3000 [00:18<00:00, 163.20it/s]

# %%
f = np.load(OUTPUT + "/1_danger_alarm_0.npy", allow_pickle=True)
print(f.shape)
print(f.dtype)
print(f"f.min():{f.min()}, f.max():{f.max()}")
# Out:
# (1, 1, 64, 101)
# float32
# f.min():0.0, f.max():255.0

# %%
file_list = sorted(glob.glob('./calibration/*.npy'))
arrays = [np.load(f) for f in file_list]
for i in range(len(arrays)):
    print(arrays[i].shape)
# Out:
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# (1, 1, 64, 101)
# ...

# %%
calib_dataset = np.concatenate(arrays, axis=0)
np.save("./calib_dataset.npy", calib_dataset)

# %%
cal = np.load("./calib_dataset.npy").astype(np.uint8)
print(cal.shape)
print(cal.dtype)
print(cal.min(), cal.max())
# Out:
# (3000, 1, 64, 101)
# uint8
# 0 255
