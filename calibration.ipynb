# %%
import os
import torch
import torch.nn.functional as F
import torchaudio
import numpy as np
from model.stft import AudioPreprocessor
from tqdm import tqdm

# %%
DATASET = ".\\Dataset"
OUTPUT = ".\\calibration"

SAMPLE_RATE = 16000
DURATION = 1
NUM_SAMPLES = SAMPLE_RATE * DURATION
WINDOW_SIZE = 512
HOP_SIZE = 160
MEL_BINS = 64
FMIN = 50
FMAX = 8000

# %%
os.makedirs(OUTPUT, exist_ok=True)

audio_preprocess = AudioPreprocessor(
    sample_rate=SAMPLE_RATE,
    window_size=WINDOW_SIZE,
    hop_size=HOP_SIZE,
    mel_bins=MEL_BINS,
    fmin=FMIN,
    fmax=FMAX
)

# %%
def convert_logmel(file_path):
    waveform, sr = torchaudio.load(file_path)
    
    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    if sr != SAMPLE_RATE:
        resampler = torchaudio.transforms.Resample(sr, SAMPLE_RATE)
        waveform = resampler(waveform)

    if waveform.shape[1] < NUM_SAMPLES:
        waveform = F.pad(waveform, (0, NUM_SAMPLES - waveform.shape[1]))
    else:
        waveform = waveform[:, :NUM_SAMPLES]

    waveform = waveform / (waveform.abs().max() + 1e-9)

    with torch.no_grad():
        logmel = audio_preprocess(waveform)

        if logmel.shape[2] < 101:
            logmel = F.pad(logmel, (0, 101 - logmel.shape[2]))

        elif logmel.shape[2] > 101:
            logmel = logmel[:, :, :101]

    return logmel.numpy()

# %%
filepaths = []

for root, _, files in os.walk(DATASET):
    
    for file in files:
        if file.lower().endswith(".wav"):
            filepaths.append(os.path.join(root, file))

print(filepaths)
# Out:
# ['.\\Dataset\\danger\\1_danger_alarm_0.wav', '.\\Dataset\\danger\\1_danger_alarm_1.wav', '.\\Dataset\\danger\\1_danger_alarm_10.wav', '.\\Dataset\\danger\\1_danger_alarm_100.wav', '.\\Dataset\\danger\\1_danger_alarm_101.wav', '.\\Dataset\\danger\\1_danger_alarm_102.wav', '.\\Dataset\\danger\\1_danger_alarm_103.wav', '.\\Dataset\\danger\\1_danger_alarm_104.wav', '.\\Dataset\\danger\\1_danger_alarm_105.wav', '.\\Dataset\\danger\\1_danger_alarm_106.wav', '.\\Dataset\\danger\\1_danger_alarm_107.wav', '.\\Dataset\\danger\\1_danger_alarm_108.wav', '.\\Dataset\\danger\\1_danger_alarm_109.wav', '.\\Dataset\\danger\\1_danger_alarm_11.wav', '.\\Dataset\\danger\\1_danger_alarm_110.wav', '.\\Dataset\\danger\\1_danger_alarm_111.wav', '.\\Dataset\\danger\\1_danger_alarm_112.wav', '.\\Dataset\\danger\\1_danger_alarm_113.wav', '.\\Dataset\\danger\\1_danger_alarm_114.wav', '.\\Dataset\\danger\\1_danger_alarm_115.wav', '.\\Dataset\\danger\\1_danger_alarm_116.wav', '.\\Dataset\\danger\\1_danger_alarm_117.wav', '.\\Dataset\\danger\\1_danger_alarm_118.wav', '.\\Dataset\\danger\\1_danger_alarm_119.wav', '.\\Dataset\\danger\\1_danger_alarm_12.wav', '.\\Dataset\\danger\\1_danger_alarm_120.wav', '.\\Dataset\\danger\\1_danger_alarm_121.wav', '.\\Dataset\\danger\\1_danger_alarm_122.wav', '.\\Dataset\\danger\\1_danger_alarm_123.wav', '.\\Dataset\\danger\\1_danger_alarm_124.wav', '.\\Dataset\\danger\\1_danger_alarm_125.wav', '.\\Dataset\\danger\\1_danger_alarm_126.wav', '.\\Dataset\\danger\\1_danger_alarm_127.wav', '.\\Dataset\\danger\\1_danger_alarm_128.wav', '.\\Dataset\\danger\\1_danger_alarm_129.wav', '.\\Dataset\\danger\\1_danger_alarm_13.wav', '.\\Dataset\\danger\\1_danger_alarm_130.wav', '.\\Dataset\\danger\\1_danger_alarm_131.wav', '.\\Dataset\\danger\\1_danger_alarm_132.wav', '.\\Dataset\\danger\\1_danger_alarm_133.wav', '.\\Dataset\\danger\\1_danger_alarm_134.wav', '.\\Dataset\\danger\\1_danger_alarm_135.wav', '.\\Dataset\\danger\\1_danger_alarm_136.wav', '.\\Dataset\\danger\\1_danger_alarm_137.wav', '.\\Dataset\\danger\\1_danger_alarm_138.wav', '.\\Dataset\\danger\\1_danger_alarm_139.wav', '.\\Dataset\\danger\\1_danger_alarm_14.wav', '.\\Dataset\\danger\\1_danger_alarm_140.wav', '.\\Dataset\\danger\\1_danger_alarm_141.wav', '.\\Dataset\\danger\\1_danger_alarm_142.wav', '.\\Dataset\\danger\\1_danger_alarm_143.wav', '.\\Dataset\\danger\\1_danger_alarm_144.wav', '.\\Dataset\\danger\\1_danger_alarm_145.wav', '.\\Dataset\\danger\\1_danger_alarm_146.wav', '.\\Dataset\\danger\\1_danger_alarm_147.wav', '.\\Dataset\\danger\\1_danger_alarm_148.wav', '.\\Dataset\\danger\\1_danger_alarm_149.wav', '.\\Dataset\\danger\\1_danger_alarm_15.wav', '.\\Dataset\\danger\\1_danger_alarm_150.wav', '.\\Dataset\\danger\\1_danger_alarm_151.wav', '.\\Dataset\\danger\\1_danger_alarm_152.wav', '.\\Dataset\\danger\\1_danger_alarm_153.wav', '.\\Dataset\\danger\\1_danger_alarm_154.wav', '.\\Dataset\\danger\\1_danger_alarm_155.wav', '.\\Dataset\\danger\\1_danger_alarm_156.wav', '.\\Dataset\\danger\\1_danger_alarm_157.wav', '.\\Dataset\\danger\\1_danger_alarm_158.wav', '.\\Dataset\\danger\\1_danger_alarm_159.wav', '.\\Dataset\\danger\\1_danger_alarm_16.wav', '.\\Dataset\\danger\\1_danger_alarm_160.wav', '.\\Dataset\\danger\\1_danger_alarm_161.wav', '.\\Dataset\\danger\\1_danger_alarm_162.wav', '.\\Dataset\\danger\\1_danger_alarm_163.wav', '.\\Dataset\\danger\\1_danger_alarm_164.wav', '.\\Dataset\\danger\\1_danger_alarm_165.wav', '.\\Dataset\\danger\\1_danger_alarm_166.wav', '.\\Dataset\\danger\\1_danger_alarm_167.wav', '.\\Dataset\\danger\\1_danger_alarm_168.wav', '.\\Dataset\\danger\\1_danger_alarm_169.wav', '.\\Dataset\\danger\\1_danger_alarm_17.wav', '.\\Dataset\\danger\\1_danger_alarm_170.wav', '.\\Dataset\\danger\\1_danger_alarm_171.wav', '.\\Dataset\\danger\\1_danger_alarm_172.wav', '.\\Dataset\\danger\\1_danger_alarm_173.wav', '.\\Dataset\\danger\\1_danger_alarm_174.wav', '.\\Dataset\\danger\\1_danger_alarm_175.wav', '.\\Dataset\\danger\\1_danger_alarm_176.wav', '.\\Datas ...

# %%
for path in tqdm(filepaths, desc="file convert", leave=True):
    file = path.split("\\")[-1]
    # print(file)
    data = convert_logmel(path)
    # print(data.shape)
    output = os.path.join(OUTPUT, file.replace(".wav", ".npy"))
    # print(output)
    np.save(output, data)
    # break
# Out:
# file convert: 100%|██████████| 3000/3000 [00:05<00:00, 574.67it/s]
